# %%
import matplotlib.pyplot as plt
import numpy as np
import math

# %%
x = np.arange(1, 5.67 , 0.001)

y = (4 - 10/(x+1))


plt.plot(x,y , "black" , linewidth = 12)

plt.show()

# %%
x1 = np.arange(2.4 , 5.67 , 0.001)
y1 = (4 - 10/(x1+1)) - 1

plt.plot(x,y , "black" , linewidth = 12)
plt.plot(x1,y1 , "black" , linewidth = 12)

plt.show()

# %%
x2 = np.arange(5.55666 , 12.0 , 0.0001)
y2 = (2.88 - np.exp((- 0.7 * x2 + 3)))

plt.plot(x,y , "black" , linewidth = 12)
plt.plot(x1,y1 , "black" , linewidth = 12)
plt.plot(x2,y2, "black" , linewidth = 12)

plt.show()

# %%
x3 = np.arange(11.99666 , 13.0 , 0.00001)
y3 =  (2.77 + np.exp(((1.2 * x3) - 16.555)))

plt.plot(x,y , "black" , linewidth = 12)
plt.plot(x1,y1 , "black" , linewidth = 12)
plt.plot(x2,y2, "black" , linewidth = 12)
plt.plot(x3,y3 , "black" , linewidth = 12)

plt.show()

# %%
plt.figure(figsize = (15 , 5) )
x4 = np.arange(1, 5.67 , 0.001)

y4 = (4 - 10/(x4+1))

plt.plot(x,y , "black" , linewidth = 12)
plt.plot(x1,y1 , "black" , linewidth = 12)
plt.plot(x2,y2, "black" , linewidth = 12)
plt.plot(x3,y3 , "black" , linewidth = 12)
plt.plot(-x4,y4, "black" , linewidth = 12)

plt.show()

# %%
x5 = np.arange(5.55666 , 8.0 , 0.001 )

y5 = (2.88 - np.exp((- 0.7 * x5 + 3))) - 1

plt.figure(figsize = (15 , 5) )
plt.plot(x,y , "black" , linewidth = 12)
plt.plot(x1,y1 , "black" , linewidth = 12)
plt.plot(x2,y2, "black" , linewidth = 12)
plt.plot(x3,y3 , "black" , linewidth = 12)
plt.plot(-x4,y4, "black" , linewidth = 12)
plt.plot(x5 , y5, "black" , linewidth = 12)

plt.show()

# %%
x6 = np.arange(1.19998, 2.4 , 0.001)

y6 = -0.03 + np.sin(x6-2.3)

plt.figure(figsize = (15 , 5) )
plt.plot(x,y , "black" , linewidth = 12)
plt.plot(x1,y1 , "black" , linewidth = 12)
plt.plot(x2,y2, "black" , linewidth = 12)
plt.plot(x3,y3 , "black" , linewidth = 12)
plt.plot(-x4,y4, "black" , linewidth = 12)
plt.plot(x5 , y5, "black" , linewidth = 12)
plt.plot(x6 , y6, "black" , linewidth = 12)
plt.show()

# %%
x7 = np.arange(8.0 , 10.25 ,0.001 )

y7 = 1.684 + 1.5 * np.exp(x7 - 10.5)

plt.figure(figsize = (15 , 5) )
plt.plot(x,y , "black" , linewidth = 12)
plt.plot(x1,y1 , "black" , linewidth = 12)
plt.plot(x2,y2, "black" , linewidth = 12)
plt.plot(x3,y3 , "black" , linewidth = 12)
plt.plot(-x4,y4, "black" , linewidth = 12)
plt.plot(x5 , y5, "black" , linewidth = 12)
plt.plot(x6 , y6, "black" , linewidth = 12)
plt.plot(x7,y7, "black" , linewidth = 12)

plt.show()

# %%
plt.figure(figsize = (15 , 5) )
plt.plot(x,y , "black" , linewidth = 12)
plt.plot(x1,y1 , "black" , linewidth = 12)
plt.plot(x2,y2, "black" , linewidth = 12)
plt.plot(x3,y3 , "black" , linewidth = 12)
plt.plot(-x4,y4, "black" , linewidth = 12)
plt.plot(x5 , y5, "black" , linewidth = 12)
plt.plot(x6 , y6, "black" , linewidth = 12)
plt.plot(x7,y7, "black" , linewidth = 12)
plt.plot(x7,y7, "black" , linewidth = 12)

plt.show()

# %%
x8 = np.arange(1.5, 2.4 , 0.001)

y8 = -0.03 + np.sin(x8-2.3) - 1.8

plt.figure(figsize = (15 , 5) )
plt.plot(x,y , "black" , linewidth = 12)
plt.plot(x1,y1 , "black" , linewidth = 12)
plt.plot(x2,y2, "black" , linewidth = 12)
plt.plot(x3,y3 , "black" , linewidth = 12)
plt.plot(-x4,y4, "black" , linewidth = 12)
plt.plot(x5 , y5, "black" , linewidth = 12)
plt.plot(x6 , y6, "black" , linewidth = 12)
plt.plot(x7,y7, "black" , linewidth = 12)
plt.plot(x8 , y8, "black" , linewidth = 12)
plt.show()

# %%
x9 = np.arange(5.55666 , 8.0 , 0.001 )

y9 = (2.88 - np.exp((- 0.7 * x9 + 3))) - 1 - 1.8

plt.figure(figsize = (15 , 5) )
plt.plot(x,y , "black" , linewidth = 12)
plt.plot(x1,y1 , "black" , linewidth = 12)
plt.plot(x2,y2, "black" , linewidth = 12)
plt.plot(x3,y3 , "black" , linewidth = 12)
plt.plot(-x4,y4, "black" , linewidth = 12)
plt.plot(x5 , y5, "black" , linewidth = 12)
plt.plot(x6 , y6, "black" , linewidth = 12)
plt.plot(x7,y7, "black" , linewidth = 12)
plt.plot(x8 , y8, "black" , linewidth = 12)
plt.plot(x9,y9, "black" , linewidth = 12)

plt.show()

# %%
x10 = np.arange(5.55666 , 7.5 , 0.001 )

y10 = (2.88 - np.exp((- 0.7 * x10 + 3))) - 1 - 1.8 - 0.75

plt.figure(figsize = (15 , 5) )
plt.plot(x,y , "black" , linewidth = 12)
plt.plot(x1,y1 , "black" , linewidth = 12)
plt.plot(x2,y2, "black" , linewidth = 12)
plt.plot(x3,y3 , "black" , linewidth = 12)
plt.plot(-x4,y4, "black" , linewidth = 12)
plt.plot(x5 , y5, "black" , linewidth = 12)
plt.plot(x6 , y6, "black" , linewidth = 12)
plt.plot(x7,y7, "black" , linewidth = 12)
plt.plot(x8 , y8, "black" , linewidth = 12)
plt.plot(x9,y9, "black" , linewidth = 12)
plt.plot(x10,y10, "black" , linewidth = 12)

plt.show()

# %%
x11 = np.arange(2.4 , 5.67 , 0.001)
y11 = (4 - 10/(x11+1)) - 1 - 1.8

plt.figure(figsize = (15 , 5) )
plt.plot(x,y , "black" , linewidth = 12)
plt.plot(x1,y1 , "black" , linewidth = 12)
plt.plot(x2,y2, "black" , linewidth = 12)
plt.plot(x3,y3 , "black" , linewidth = 12)
plt.plot(-x4,y4, "black" , linewidth = 12)
plt.plot(x5 , y5, "black" , linewidth = 12)
plt.plot(x6 , y6, "black" , linewidth = 12)
plt.plot(x7,y7, "black" , linewidth = 12)
plt.plot(x8 , y8, "black" , linewidth = 12)
plt.plot(x9,y9, "black" , linewidth = 12)
plt.plot(x10,y10, "black" , linewidth = 12)
plt.plot(x11,y11, "black" , linewidth = 12)

plt.show()

# %%
x12 = np.arange(2.4 , 5.67 , 0.001)
y12 = (4 - 10/(x12+1)) - 1 - 1.8 - 0.75

plt.figure(figsize = (15 , 5) )
plt.plot(x,y , "black" , linewidth = 12)
plt.plot(x1,y1 , "black" , linewidth = 12)
plt.plot(x2,y2, "black" , linewidth = 12)
plt.plot(x3,y3 , "black" , linewidth = 12)
plt.plot(-x4,y4, "black" , linewidth = 12)
plt.plot(x5 , y5, "black" , linewidth = 12)
plt.plot(x6 , y6, "black" , linewidth = 12)
plt.plot(x7,y7, "black" , linewidth = 12)
plt.plot(x8 , y8, "black" , linewidth = 12)
plt.plot(x9,y9, "black" , linewidth = 12)
plt.plot(x10,y10, "black" , linewidth = 12)
plt.plot(x11,y11, "black" , linewidth = 12)
plt.plot(x12,y12, "black" , linewidth = 12)

plt.show()

# %%
x13 = np.arange(8.0 , 10 ,0.001 )

y13 = 1.684 + 1.5 * np.exp(x13 - 10.5) - 1.8

plt.figure(figsize = (15 , 5) )
plt.plot(x,y , "black" , linewidth = 12)
plt.plot(x1,y1 , "black" , linewidth = 12)
plt.plot(x2,y2, "black" , linewidth = 12)
plt.plot(x3,y3 , "black" , linewidth = 12)
plt.plot(-x4,y4, "black" , linewidth = 12)
plt.plot(x5 , y5, "black" , linewidth = 12)
plt.plot(x6 , y6, "black" , linewidth = 12)
plt.plot(x7,y7, "black" , linewidth = 12)
plt.plot(x8 , y8, "black" , linewidth = 12)
plt.plot(x9,y9, "black" , linewidth = 12)
plt.plot(x10,y10, "black" , linewidth = 12)
plt.plot(x11,y11, "black" , linewidth = 12)
plt.plot(x12,y12, "black" , linewidth = 12)
plt.plot(x13,y13, "black" , linewidth = 12)

plt.show()

# %%
x14 = np.arange(7.5 , 9.25 ,0.001 )

y14 = -1.01 + 1.35 * np.exp(x14 - 9.25)

plt.figure(figsize = (15 , 5) )
plt.plot(x,y , "black" , linewidth = 12)
plt.plot(x1,y1 , "black" , linewidth = 12)
plt.plot(x2,y2, "black" , linewidth = 12)
plt.plot(x3,y3 , "black" , linewidth = 12)
plt.plot(-x4,y4, "black" , linewidth = 12)
plt.plot(x5 , y5, "black" , linewidth = 12)
plt.plot(x6 , y6, "black" , linewidth = 12)
plt.plot(x7,y7, "black" , linewidth = 12)
plt.plot(x8 , y8, "black" , linewidth = 12)
plt.plot(x9,y9, "black" , linewidth = 12)
plt.plot(x10,y10, "black" , linewidth = 12)
plt.plot(x11,y11, "black" , linewidth = 12)
plt.plot(x12,y12, "black" , linewidth = 12)
plt.plot(x13,y13, "black" , linewidth = 12)
plt.plot(x14,y14, "black" , linewidth = 12)

plt.show()

# %%
x15 = np.arange(2.4 , 8.75 , 0.001)

y15 = -3.5 + 0.2 * (x15 - 4.7)*(x15 - 4.7)

plt.figure(figsize = (15 , 5) )
plt.plot(x,y , "black" , linewidth = 12)
plt.plot(x1,y1 , "black" , linewidth = 12)
plt.plot(x2,y2, "black" , linewidth = 12)
plt.plot(x3,y3 , "black" , linewidth = 12)
plt.plot(-x4,y4, "black" , linewidth = 12)
plt.plot(x5 , y5, "black" , linewidth = 12)
plt.plot(x6 , y6, "black" , linewidth = 12)
plt.plot(x7,y7, "black" , linewidth = 12)
plt.plot(x8 , y8, "black" , linewidth = 12)
plt.plot(x9,y9, "black" , linewidth = 12)
plt.plot(x10,y10, "black" , linewidth = 12)
plt.plot(x11,y11, "black" , linewidth = 12)
plt.plot(x12,y12, "black" , linewidth = 12)
plt.plot(x13,y13, "black" , linewidth = 12)
plt.plot(x14,y14, "black" , linewidth = 12)
plt.plot(x15 , y15, "black" , linewidth = 12)

# %%
x16 = np.arange(1.53 , 9.6 , 0.001)

y16 = -4.2 + 0.185 * (x16 - 4.55) * (x16 - 4.55)

plt.figure(figsize = (15 , 5) )
plt.plot(x,y , "black" , linewidth = 12)
plt.plot(x1,y1 , "black" , linewidth = 12)
plt.plot(x2,y2, "black" , linewidth = 12)
plt.plot(x3,y3 , "black" , linewidth = 12)
plt.plot(-x4,y4, "black" , linewidth = 12)
plt.plot(x5 , y5, "black" , linewidth = 12)
plt.plot(x6 , y6, "black" , linewidth = 12)
plt.plot(x7,y7, "black" , linewidth = 12)
plt.plot(x8 , y8, "black" , linewidth = 12)
plt.plot(x9,y9, "black" , linewidth = 12)
plt.plot(x10,y10, "black" , linewidth = 12)
plt.plot(x11,y11, "black" , linewidth = 12)
plt.plot(x12,y12, "black" , linewidth = 12)
plt.plot(x13,y13, "black" , linewidth = 12)
plt.plot(x14,y14, "black" , linewidth = 12)
plt.plot(x15 , y15, "black" , linewidth = 12)
plt.plot(x16 , y16, "black" , linewidth = 12)

# %%
plt.figure(figsize = (15 , 5) )
plt.plot(x,y , "black" , linewidth = 12)
plt.plot(x1,y1 , "black" , linewidth = 12)
plt.plot(x2,y2, "black" , linewidth = 12)
plt.plot(x3,y3 , "black" , linewidth = 12)
plt.plot(-x4,y4, "black" , linewidth = 12)
plt.plot(x5 , y5, "black" , linewidth = 12)
plt.plot(x6 , y6, "black" , linewidth = 12)
plt.plot(x7,y7, "black" , linewidth = 12)
plt.plot(x8 , y8, "black" , linewidth = 12)
plt.plot(x9,y9, "black" , linewidth = 12)
plt.plot(x10,y10, "black" , linewidth = 12)
plt.plot(x11,y11, "black" , linewidth = 12)
plt.plot(x12,y12, "black" , linewidth = 12)
plt.plot(x13,y13, "black" , linewidth = 12)
plt.plot(x14,y14, "black" , linewidth = 12)
plt.plot(x15 , y15, "black" , linewidth = 12)
plt.plot(x16 , y16, "black" , linewidth = 12)
plt.scatter(5,-2.35 , s = 5000 ,facecolors = "gray" ,edgecolors="black" , linewidth = 10.5)

# %%
plt.figure(figsize = (15 , 5) )
plt.plot(x,y , "black" , linewidth = 12)
plt.plot(x1,y1 , "black" , linewidth = 12)
plt.plot(x2,y2, "black" , linewidth = 12)
plt.plot(x3,y3 , "black" , linewidth = 12)
plt.plot(-x4,y4, "black" , linewidth = 12)
plt.plot(x5 , y5, "black" , linewidth = 12)
plt.plot(x6 , y6, "black" , linewidth = 12)
plt.plot(x7,y7, "black" , linewidth = 12)
plt.plot(x8 , y8, "black" , linewidth = 12)
plt.plot(x9,y9, "black" , linewidth = 12)
plt.plot(x10,y10, "black" , linewidth = 12)
plt.plot(x11,y11, "black" , linewidth = 12)
plt.plot(x12,y12, "black" , linewidth = 12)
plt.plot(x13,y13, "black" , linewidth = 12)
plt.plot(x14,y14, "black" , linewidth = 12)
plt.plot(x15 , y15, "black" , linewidth = 12)
plt.plot(x16 , y16, "black" , linewidth = 12)
plt.scatter(5,-2.35 , s = 5000 ,facecolors = "gray" ,edgecolors="black" , linewidth = 10.5)
plt.plot(-x1,y1 , "black" , linewidth = 12)

# %%
plt.figure(figsize = (20 , 5) )
plt.plot(x,y , "black" , linewidth = 12)
plt.plot(x1,y1 , "black" , linewidth = 12)
plt.plot(x2,y2, "black" , linewidth = 12)
plt.plot(x3,y3 , "black" , linewidth = 12)
plt.plot(-x4,y4, "black" , linewidth = 12)
plt.plot(x5 , y5, "black" , linewidth = 12)
plt.plot(x6 , y6, "black" , linewidth = 12)
plt.plot(x7,y7, "black" , linewidth = 12)
plt.plot(x8 , y8, "black" , linewidth = 12)
plt.plot(x9,y9, "black" , linewidth = 12)
plt.plot(x10,y10, "black" , linewidth = 12)
plt.plot(x11,y11, "black" , linewidth = 12)
plt.plot(x12,y12, "black" , linewidth = 12)
plt.plot(x13,y13, "black" , linewidth = 12)
plt.plot(x14,y14, "black" , linewidth = 12)
plt.plot(x15 , y15, "black" , linewidth = 12)
plt.plot(x16 , y16, "black" , linewidth = 12)
plt.scatter(5,-2.35 , s = 5000 ,facecolors = "gray" ,edgecolors="black" , linewidth = 10.5)
plt.plot(-x1,y1 , "black" , linewidth = 12)
plt.plot(-x2,y2 , "black" , linewidth = 12)

# %%
plt.figure(figsize = (15 , 5) )
plt.plot(x,y , "black" , linewidth = 12)
plt.plot(x1,y1 , "black" , linewidth = 12)
plt.plot(x2,y2, "black" , linewidth = 12)
plt.plot(x3,y3 , "black" , linewidth = 12)
plt.plot(-x4,y4, "black" , linewidth = 12)
plt.plot(x5 , y5, "black" , linewidth = 12)
plt.plot(x6 , y6, "black" , linewidth = 12)
plt.plot(x7,y7, "black" , linewidth = 12)
plt.plot(x8 , y8, "black" , linewidth = 12)
plt.plot(x9,y9, "black" , linewidth = 12)
plt.plot(x10,y10, "black" , linewidth = 12)
plt.plot(x11,y11, "black" , linewidth = 12)
plt.plot(x12,y12, "black" , linewidth = 12)
plt.plot(x13,y13, "black" , linewidth = 12)
plt.plot(x14,y14, "black" , linewidth = 12)
plt.plot(x15 , y15, "black" , linewidth = 12)
plt.plot(x16 , y16, "black" , linewidth = 12)
plt.scatter(5,-2.35 , s = 5000 ,facecolors = "gray" ,edgecolors="black" , linewidth = 10.5)
plt.plot(-x1,y1 , "black" , linewidth = 12)
plt.plot(-x2,y2 , "black" , linewidth = 12)
plt.plot(-x3,y3 , "black" , linewidth = 12)

# %%
plt.figure(figsize = (15 , 5) )
plt.plot(x,y , "black" , linewidth = 12)
plt.plot(x1,y1 , "black" , linewidth = 12)
plt.plot(x2,y2, "black" , linewidth = 12)
plt.plot(x3,y3 , "black" , linewidth = 12)
plt.plot(-x4,y4, "black" , linewidth = 12)
plt.plot(x5 , y5, "black" , linewidth = 12)
plt.plot(x6 , y6, "black" , linewidth = 12)
plt.plot(x7,y7, "black" , linewidth = 12)
plt.plot(x8 , y8, "black" , linewidth = 12)
plt.plot(x9,y9, "black" , linewidth = 12)
plt.plot(x10,y10, "black" , linewidth = 12)
plt.plot(x11,y11, "black" , linewidth = 12)
plt.plot(x12,y12, "black" , linewidth = 12)
plt.plot(x13,y13, "black" , linewidth = 12)
plt.plot(x14,y14, "black" , linewidth = 12)
plt.plot(x15 , y15, "black" , linewidth = 12)
plt.plot(x16 , y16, "black" , linewidth = 12)
plt.scatter(5,-2.35 , s = 5000 ,facecolors = "gray" ,edgecolors="black" , linewidth = 10.5)
plt.plot(-x1,y1 , "black" , linewidth = 12)
plt.plot(-x2,y2 , "black" , linewidth = 12)
plt.plot(-x3,y3 , "black" , linewidth = 12)
plt.plot(-x5 , y5 , "black" , linewidth = 12)

# %%
plt.figure(figsize = (15 , 5) )
plt.plot(x,y , "black" , linewidth = 12)
plt.plot(x1,y1 , "black" , linewidth = 12)
plt.plot(x2,y2, "black" , linewidth = 12)
plt.plot(x3,y3 , "black" , linewidth = 12)
plt.plot(-x4,y4, "black" , linewidth = 12)
plt.plot(x5 , y5, "black" , linewidth = 12)
plt.plot(x6 , y6, "black" , linewidth = 12)
plt.plot(x7,y7, "black" , linewidth = 12)
plt.plot(x8 , y8, "black" , linewidth = 12)
plt.plot(x9,y9, "black" , linewidth = 12)
plt.plot(x10,y10, "black" , linewidth = 12)
plt.plot(x11,y11, "black" , linewidth = 12)
plt.plot(x12,y12, "black" , linewidth = 12)
plt.plot(x13,y13, "black" , linewidth = 12)
plt.plot(x14,y14, "black" , linewidth = 12)
plt.plot(x15 , y15, "black" , linewidth = 12)
plt.plot(x16 , y16, "black" , linewidth = 12)
plt.scatter(5,-2.35 , s = 5000 ,facecolors = "gray" ,edgecolors="black" , linewidth = 10.5)
plt.plot(-x1,y1 , "black" , linewidth = 12)
plt.plot(-x2,y2 , "black" , linewidth = 12)
plt.plot(-x3,y3 , "black" , linewidth = 12)
plt.plot(-x5 , y5 , "black" , linewidth = 12)
plt.plot(-x6 , y6 , "black" , linewidth = 12)

# %%
plt.figure(figsize = (15 , 5) )
plt.plot(x,y , "black" , linewidth = 12)
plt.plot(x1,y1 , "black" , linewidth = 12)
plt.plot(x2,y2, "black" , linewidth = 12)
plt.plot(x3,y3 , "black" , linewidth = 12)
plt.plot(-x4,y4, "black" , linewidth = 12)
plt.plot(x5 , y5, "black" , linewidth = 12)
plt.plot(x6 , y6, "black" , linewidth = 12)
plt.plot(x7,y7, "black" , linewidth = 12)
plt.plot(x8 , y8, "black" , linewidth = 12)
plt.plot(x9,y9, "black" , linewidth = 12)
plt.plot(x10,y10, "black" , linewidth = 12)
plt.plot(x11,y11, "black" , linewidth = 12)
plt.plot(x12,y12, "black" , linewidth = 12)
plt.plot(x13,y13, "black" , linewidth = 12)
plt.plot(x14,y14, "black" , linewidth = 12)
plt.plot(x15 , y15, "black" , linewidth = 12)
plt.plot(x16 , y16, "black" , linewidth = 12)
plt.scatter(5,-2.35 , s = 5000 ,facecolors = "gray" ,edgecolors="black" , linewidth = 10.5)
plt.plot(-x1,y1 , "black" , linewidth = 12)
plt.plot(-x2,y2 , "black" , linewidth = 12)
plt.plot(-x3,y3 , "black" , linewidth = 12)
plt.plot(-x5 , y5 , "black" , linewidth = 12)
plt.plot(-x6 , y6 , "black" , linewidth = 12)
plt.plot(-x7,y7 , "black" , linewidth = 12)

# %%
plt.figure(figsize = (15 , 5) )
plt.plot(x,y , "black" , linewidth = 12)
plt.plot(x1,y1 , "black" , linewidth = 12)
plt.plot(x2,y2, "black" , linewidth = 12)
plt.plot(x3,y3 , "black" , linewidth = 12)
plt.plot(-x4,y4, "black" , linewidth = 12)
plt.plot(x5 , y5, "black" , linewidth = 12)
plt.plot(x6 , y6, "black" , linewidth = 12)
plt.plot(x7,y7, "black" , linewidth = 12)
plt.plot(x8 , y8, "black" , linewidth = 12)
plt.plot(x9,y9, "black" , linewidth = 12)
plt.plot(x10,y10, "black" , linewidth = 12)
plt.plot(x11,y11, "black" , linewidth = 12)
plt.plot(x12,y12, "black" , linewidth = 12)
plt.plot(x13,y13, "black" , linewidth = 12)
plt.plot(x14,y14, "black" , linewidth = 12)
plt.plot(x15 , y15, "black" , linewidth = 12)
plt.plot(x16 , y16, "black" , linewidth = 12)
plt.scatter(5,-2.35 , s = 5000 ,facecolors = "gray" ,edgecolors="black" , linewidth = 10.5)
plt.plot(-x1,y1 , "black" , linewidth = 12)
plt.plot(-x2,y2 , "black" , linewidth = 12)
plt.plot(-x3,y3 , "black" , linewidth = 12)
plt.plot(-x5 , y5 , "black" , linewidth = 12)
plt.plot(-x6 , y6 , "black" , linewidth = 12)
plt.plot(-x7,y7 , "black" , linewidth = 12)
plt.plot(-x8 , y8  , "black" , linewidth = 12)

# %%
plt.figure(figsize = (15 , 5) )
plt.plot(x,y , "black" , linewidth = 12)
plt.plot(x1,y1 , "black" , linewidth = 12)
plt.plot(x2,y2, "black" , linewidth = 12)
plt.plot(x3,y3 , "black" , linewidth = 12)
plt.plot(-x4,y4, "black" , linewidth = 12)
plt.plot(x5 , y5, "black" , linewidth = 12)
plt.plot(x6 , y6, "black" , linewidth = 12)
plt.plot(x7,y7, "black" , linewidth = 12)
plt.plot(x8 , y8, "black" , linewidth = 12)
plt.plot(x9,y9, "black" , linewidth = 12)
plt.plot(x10,y10, "black" , linewidth = 12)
plt.plot(x11,y11, "black" , linewidth = 12)
plt.plot(x12,y12, "black" , linewidth = 12)
plt.plot(x13,y13, "black" , linewidth = 12)
plt.plot(x14,y14, "black" , linewidth = 12)
plt.plot(x15 , y15, "black" , linewidth = 12)
plt.plot(x16 , y16, "black" , linewidth = 12)
plt.scatter(5,-2.35 , s = 5000 ,facecolors = "gray" ,edgecolors="black" , linewidth = 10.5)
plt.plot(-x1,y1 , "black" , linewidth = 12)
plt.plot(-x2,y2 , "black" , linewidth = 12)
plt.plot(-x3,y3 , "black" , linewidth = 12)
plt.plot(-x5 , y5 , "black" , linewidth = 12)
plt.plot(-x6 , y6 , "black" , linewidth = 12)
plt.plot(-x7,y7 , "black" , linewidth = 12)
plt.plot(-x8 , y8  , "black" , linewidth = 12)
plt.plot(-x9,y9 , "black" , linewidth = 12 )

# %%
plt.figure(figsize = (15 , 5) )
plt.plot(x,y , "black" , linewidth = 12)
plt.plot(x1,y1 , "black" , linewidth = 12)
plt.plot(x2,y2, "black" , linewidth = 12)
plt.plot(x3,y3 , "black" , linewidth = 12)
plt.plot(-x4,y4, "black" , linewidth = 12)
plt.plot(x5 , y5, "black" , linewidth = 12)
plt.plot(x6 , y6, "black" , linewidth = 12)
plt.plot(x7,y7, "black" , linewidth = 12)
plt.plot(x8 , y8, "black" , linewidth = 12)
plt.plot(x9,y9, "black" , linewidth = 12)
plt.plot(x10,y10, "black" , linewidth = 12)
plt.plot(x11,y11, "black" , linewidth = 12)
plt.plot(x12,y12, "black" , linewidth = 12)
plt.plot(x13,y13, "black" , linewidth = 12)
plt.plot(x14,y14, "black" , linewidth = 12)
plt.plot(x15 , y15, "black" , linewidth = 12)
plt.plot(x16 , y16, "black" , linewidth = 12)
plt.scatter(5,-2.35 , s = 5000 ,facecolors = "gray" ,edgecolors="black" , linewidth = 10.5)
plt.plot(-x1,y1 , "black" , linewidth = 12)
plt.plot(-x2,y2 , "black" , linewidth = 12)
plt.plot(-x3,y3 , "black" , linewidth = 12)
plt.plot(-x5 , y5 , "black" , linewidth = 12)
plt.plot(-x6 , y6 , "black" , linewidth = 12)
plt.plot(-x7,y7 , "black" , linewidth = 12)
plt.plot(-x8 , y8  , "black" , linewidth = 12)
plt.plot(-x9,y9 , "black" , linewidth = 12 )
plt.plot(-x10,y10 , "black" , linewidth = 12 )

# %%
plt.figure(figsize = (15 , 5) )
plt.plot(x,y , "black" , linewidth = 12)
plt.plot(x1,y1 , "black" , linewidth = 12)
plt.plot(x2,y2, "black" , linewidth = 12)
plt.plot(x3,y3 , "black" , linewidth = 12)
plt.plot(-x4,y4, "black" , linewidth = 12)
plt.plot(x5 , y5, "black" , linewidth = 12)
plt.plot(x6 , y6, "black" , linewidth = 12)
plt.plot(x7,y7, "black" , linewidth = 12)
plt.plot(x8 , y8, "black" , linewidth = 12)
plt.plot(x9,y9, "black" , linewidth = 12)
plt.plot(x10,y10, "black" , linewidth = 12)
plt.plot(x11,y11, "black" , linewidth = 12)
plt.plot(x12,y12, "black" , linewidth = 12)
plt.plot(x13,y13, "black" , linewidth = 12)
plt.plot(x14,y14, "black" , linewidth = 12)
plt.plot(x15 , y15, "black" , linewidth = 12)
plt.plot(x16 , y16, "black" , linewidth = 12)
plt.scatter(5,-2.35 , s = 5000 ,facecolors = "gray" ,edgecolors="black" , linewidth = 10.5)
plt.plot(-x1,y1 , "black" , linewidth = 12)
plt.plot(-x2,y2 , "black" , linewidth = 12)
plt.plot(-x3,y3 , "black" , linewidth = 12)
plt.plot(-x5 , y5 , "black" , linewidth = 12)
plt.plot(-x6 , y6 , "black" , linewidth = 12)
plt.plot(-x7,y7 , "black" , linewidth = 12)
plt.plot(-x8 , y8  , "black" , linewidth = 12)
plt.plot(-x9,y9 , "black" , linewidth = 12 )
plt.plot(-x10,y10 , "black" , linewidth = 12 )

# %%
plt.figure(figsize = (15 , 5) )
plt.plot(x,y , "black" , linewidth = 12)
plt.plot(x1,y1 , "black" , linewidth = 12)
plt.plot(x2,y2, "black" , linewidth = 12)
plt.plot(x3,y3 , "black" , linewidth = 12)
plt.plot(-x4,y4, "black" , linewidth = 12)
plt.plot(x5 , y5, "black" , linewidth = 12)
plt.plot(x6 , y6, "black" , linewidth = 12)
plt.plot(x7,y7, "black" , linewidth = 12)
plt.plot(x8 , y8, "black" , linewidth = 12)
plt.plot(x9,y9, "black" , linewidth = 12)
plt.plot(x10,y10, "black" , linewidth = 12)
plt.plot(x11,y11, "black" , linewidth = 12)
plt.plot(x12,y12, "black" , linewidth = 12)
plt.plot(x13,y13, "black" , linewidth = 12)
plt.plot(x14,y14, "black" , linewidth = 12)
plt.plot(x15 , y15, "black" , linewidth = 12)
plt.plot(x16 , y16, "black" , linewidth = 12)
plt.scatter(5,-2.35 , s = 5000 ,facecolors = "gray" ,edgecolors="black" , linewidth = 10.5)
plt.plot(-x1,y1 , "black" , linewidth = 12)
plt.plot(-x2,y2 , "black" , linewidth = 12)
plt.plot(-x3,y3 , "black" , linewidth = 12)
plt.plot(-x5 , y5 , "black" , linewidth = 12)
plt.plot(-x6 , y6 , "black" , linewidth = 12)
plt.plot(-x7,y7 , "black" , linewidth = 12)
plt.plot(-x8 , y8  , "black" , linewidth = 12)
plt.plot(-x9,y9 , "black" , linewidth = 12 )
plt.plot(-x10,y10 , "black" , linewidth = 12 )
plt.plot(-x11,y11  , "black" , linewidth = 12 )

# %%
plt.figure(figsize = (15 , 5) )
plt.plot(x,y , "black" , linewidth = 12)
plt.plot(x1,y1 , "black" , linewidth = 12)
plt.plot(x2,y2, "black" , linewidth = 12)
plt.plot(x3,y3 , "black" , linewidth = 12)
plt.plot(-x4,y4, "black" , linewidth = 12)
plt.plot(x5 , y5, "black" , linewidth = 12)
plt.plot(x6 , y6, "black" , linewidth = 12)
plt.plot(x7,y7, "black" , linewidth = 12)
plt.plot(x8 , y8, "black" , linewidth = 12)
plt.plot(x9,y9, "black" , linewidth = 12)
plt.plot(x10,y10, "black" , linewidth = 12)
plt.plot(x11,y11, "black" , linewidth = 12)
plt.plot(x12,y12, "black" , linewidth = 12)
plt.plot(x13,y13, "black" , linewidth = 12)
plt.plot(x14,y14, "black" , linewidth = 12)
plt.plot(x15 , y15, "black" , linewidth = 12)
plt.plot(x16 , y16, "black" , linewidth = 12)
plt.scatter(5,-2.35 , s = 5000 ,facecolors = "gray" ,edgecolors="black" , linewidth = 10.5)
plt.plot(-x1,y1 , "black" , linewidth = 12)
plt.plot(-x2,y2 , "black" , linewidth = 12)
plt.plot(-x3,y3 , "black" , linewidth = 12)
plt.plot(-x5 , y5 , "black" , linewidth = 12)
plt.plot(-x6 , y6 , "black" , linewidth = 12)
plt.plot(-x7,y7 , "black" , linewidth = 12)
plt.plot(-x8 , y8  , "black" , linewidth = 12)
plt.plot(-x9,y9 , "black" , linewidth = 12 )
plt.plot(-x10,y10 , "black" , linewidth = 12 )
plt.plot(-x11,y11  , "black" , linewidth = 12 )
plt.plot(-x12,y12 , "black" , linewidth = 12 )

# %%
plt.figure(figsize = (15 , 5) )
plt.plot(x,y , "black" , linewidth = 12)
plt.plot(x1,y1 , "black" , linewidth = 12)
plt.plot(x2,y2, "black" , linewidth = 12)
plt.plot(x3,y3 , "black" , linewidth = 12)
plt.plot(-x4,y4, "black" , linewidth = 12)
plt.plot(x5 , y5, "black" , linewidth = 12)
plt.plot(x6 , y6, "black" , linewidth = 12)
plt.plot(x7,y7, "black" , linewidth = 12)
plt.plot(x8 , y8, "black" , linewidth = 12)
plt.plot(x9,y9, "black" , linewidth = 12)
plt.plot(x10,y10, "black" , linewidth = 12)
plt.plot(x11,y11, "black" , linewidth = 12)
plt.plot(x12,y12, "black" , linewidth = 12)
plt.plot(x13,y13, "black" , linewidth = 12)
plt.plot(x14,y14, "black" , linewidth = 12)
plt.plot(x15 , y15, "black" , linewidth = 12)
plt.plot(x16 , y16, "black" , linewidth = 12)
plt.scatter(5,-2.35 , s = 5000 ,facecolors = "gray" ,edgecolors="black" , linewidth = 10.5)
plt.plot(-x1,y1 , "black" , linewidth = 12)
plt.plot(-x2,y2 , "black" , linewidth = 12)
plt.plot(-x3,y3 , "black" , linewidth = 12)
plt.plot(-x5 , y5 , "black" , linewidth = 12)
plt.plot(-x6 , y6 , "black" , linewidth = 12)
plt.plot(-x7,y7 , "black" , linewidth = 12)
plt.plot(-x8 , y8  , "black" , linewidth = 12)
plt.plot(-x9,y9 , "black" , linewidth = 12 )
plt.plot(-x10,y10 , "black" , linewidth = 12 )
plt.plot(-x11,y11  , "black" , linewidth = 12 )
plt.plot(-x12,y12 , "black" , linewidth = 12 )
plt.plot(-x13,y13 , "black" , linewidth = 12 )

# %%
plt.figure(figsize = (15 , 5) )
plt.plot(x,y , "black" , linewidth = 12)
plt.plot(x1,y1 , "black" , linewidth = 12)
plt.plot(x2,y2, "black" , linewidth = 12)
plt.plot(x3,y3 , "black" , linewidth = 12)
plt.plot(-x4,y4, "black" , linewidth = 12)
plt.plot(x5 , y5, "black" , linewidth = 12)
plt.plot(x6 , y6, "black" , linewidth = 12)
plt.plot(x7,y7, "black" , linewidth = 12)
plt.plot(x8 , y8, "black" , linewidth = 12)
plt.plot(x9,y9, "black" , linewidth = 12)
plt.plot(x10,y10, "black" , linewidth = 12)
plt.plot(x11,y11, "black" , linewidth = 12)
plt.plot(x12,y12, "black" , linewidth = 12)
plt.plot(x13,y13, "black" , linewidth = 12)
plt.plot(x14,y14, "black" , linewidth = 12)
plt.plot(x15 , y15, "black" , linewidth = 12)
plt.plot(x16 , y16, "black" , linewidth = 12)
plt.scatter(5,-2.35 , s = 5000 ,facecolors = "gray" ,edgecolors="black" , linewidth = 10.5)
plt.plot(-x1,y1 , "black" , linewidth = 12)
plt.plot(-x2,y2 , "black" , linewidth = 12)
plt.plot(-x3,y3 , "black" , linewidth = 12)
plt.plot(-x5 , y5 , "black" , linewidth = 12)
plt.plot(-x6 , y6 , "black" , linewidth = 12)
plt.plot(-x7,y7 , "black" , linewidth = 12)
plt.plot(-x8 , y8  , "black" , linewidth = 12)
plt.plot(-x9,y9 , "black" , linewidth = 12 )
plt.plot(-x10,y10 , "black" , linewidth = 12 )
plt.plot(-x11,y11  , "black" , linewidth = 12 )
plt.plot(-x12,y12 , "black" , linewidth = 12 )
plt.plot(-x13,y13 , "black" , linewidth = 12 )
plt.plot(-x14,y14 , "black" , linewidth = 12 )

# %%
plt.figure(figsize = (15 , 5) )
plt.plot(x,y , "black" , linewidth = 12)
plt.plot(x1,y1 , "black" , linewidth = 12)
plt.plot(x2,y2, "black" , linewidth = 12)
plt.plot(x3,y3 , "black" , linewidth = 12)
plt.plot(-x4,y4, "black" , linewidth = 12)
plt.plot(x5 , y5, "black" , linewidth = 12)
plt.plot(x6 , y6, "black" , linewidth = 12)
plt.plot(x7,y7, "black" , linewidth = 12)
plt.plot(x8 , y8, "black" , linewidth = 12)
plt.plot(x9,y9, "black" , linewidth = 12)
plt.plot(x10,y10, "black" , linewidth = 12)
plt.plot(x11,y11, "black" , linewidth = 12)
plt.plot(x12,y12, "black" , linewidth = 12)
plt.plot(x13,y13, "black" , linewidth = 12)
plt.plot(x14,y14, "black" , linewidth = 12)
plt.plot(x15 , y15, "black" , linewidth = 12)
plt.plot(x16 , y16, "black" , linewidth = 12)
plt.scatter(5,-2.35 , s = 5000 ,facecolors = "gray" ,edgecolors="black" , linewidth = 10.5)
plt.plot(-x1,y1 , "black" , linewidth = 12)
plt.plot(-x2,y2 , "black" , linewidth = 12)
plt.plot(-x3,y3 , "black" , linewidth = 12)
plt.plot(-x5 , y5 , "black" , linewidth = 12)
plt.plot(-x6 , y6 , "black" , linewidth = 12)
plt.plot(-x7,y7 , "black" , linewidth = 12)
plt.plot(-x8 , y8  , "black" , linewidth = 12)
plt.plot(-x9,y9 , "black" , linewidth = 12 )
plt.plot(-x10,y10 , "black" , linewidth = 12 )
plt.plot(-x11,y11  , "black" , linewidth = 12 )
plt.plot(-x12,y12 , "black" , linewidth = 12 )
plt.plot(-x13,y13 , "black" , linewidth = 12 )
plt.plot(-x14,y14 , "black" , linewidth = 12 )
plt.plot([1.566 , 2.4]  ,  [-2.49 , -2.49] , "black" , linewidth = 12 )

# %%
plt.figure(figsize = (15 , 5) )
plt.plot(x,y , "black" , linewidth = 12)
plt.plot(x1,y1 , "black" , linewidth = 12)
plt.plot(x2,y2, "black" , linewidth = 12)
plt.plot(x3,y3 , "black" , linewidth = 12)
plt.plot(-x4,y4, "black" , linewidth = 12)
plt.plot(x5 , y5, "black" , linewidth = 12)
plt.plot(x6 , y6, "black" , linewidth = 12)
plt.plot(x7,y7, "black" , linewidth = 12)
plt.plot(x8 , y8, "black" , linewidth = 12)
plt.plot(x9,y9, "black" , linewidth = 12)
plt.plot(x10,y10, "black" , linewidth = 12)
plt.plot(x11,y11, "black" , linewidth = 12)
plt.plot(x12,y12, "black" , linewidth = 12)
plt.plot(x13,y13, "black" , linewidth = 12)
plt.plot(x14,y14, "black" , linewidth = 12)
plt.plot(x15 , y15, "black" , linewidth = 12)
plt.plot(x16 , y16, "black" , linewidth = 12)
plt.scatter(5,-2.35 , s = 5000 ,facecolors = "gray" ,edgecolors="black" , linewidth = 10.5)
plt.plot(-x1,y1 , "black" , linewidth = 12)
plt.plot(-x2,y2 , "black" , linewidth = 12)
plt.plot(-x3,y3 , "black" , linewidth = 12)
plt.plot(-x5 , y5 , "black" , linewidth = 12)
plt.plot(-x6 , y6 , "black" , linewidth = 12)
plt.plot(-x7,y7 , "black" , linewidth = 12)
plt.plot(-x8 , y8  , "black" , linewidth = 12)
plt.plot(-x9,y9 , "black" , linewidth = 12 )
plt.plot(-x10,y10 , "black" , linewidth = 12 )
plt.plot(-x11,y11  , "black" , linewidth = 12 )
plt.plot(-x12,y12 , "black" , linewidth = 12 )
plt.plot(-x13,y13 , "black" , linewidth = 12 )
plt.plot(-x14,y14 , "black" , linewidth = 12 )
plt.plot([1.566 , 2.4]  ,  [-2.49 , -2.49] , "black" , linewidth = 12 )
plt.plot([-1.566 , -2.4]  ,  [-2.49 , -2.49] , "black" , linewidth = 12 )

# %%
plt.figure(figsize = (15 , 5) )
plt.plot(x,y , "black" , linewidth = 12)
plt.plot(x1,y1 , "black" , linewidth = 12)
plt.plot(x2,y2, "black" , linewidth = 12)
plt.plot(x3,y3 , "black" , linewidth = 12)
plt.plot(-x4,y4, "black" , linewidth = 12)
plt.plot(x5 , y5, "black" , linewidth = 12)
plt.plot(x6 , y6, "black" , linewidth = 12)
plt.plot(x7,y7, "black" , linewidth = 12)
plt.plot(x8 , y8, "black" , linewidth = 12)
plt.plot(x9,y9, "black" , linewidth = 12)
plt.plot(x10,y10, "black" , linewidth = 12)
plt.plot(x11,y11, "black" , linewidth = 12)
plt.plot(x12,y12, "black" , linewidth = 12)
plt.plot(x13,y13, "black" , linewidth = 12)
plt.plot(x14,y14, "black" , linewidth = 12)
plt.plot(x15 , y15, "black" , linewidth = 12)
plt.plot(x16 , y16, "black" , linewidth = 12)
plt.scatter(5,-2.35 , s = 5000 ,facecolors = "gray" ,edgecolors="black" , linewidth = 10.5)
plt.plot(-x1,y1 , "black" , linewidth = 12)
plt.plot(-x2,y2 , "black" , linewidth = 12)
plt.plot(-x3,y3 , "black" , linewidth = 12)
plt.plot(-x5 , y5 , "black" , linewidth = 12)
plt.plot(-x6 , y6 , "black" , linewidth = 12)
plt.plot(-x7,y7 , "black" , linewidth = 12)
plt.plot(-x8 , y8  , "black" , linewidth = 12)
plt.plot(-x9,y9 , "black" , linewidth = 12 )
plt.plot(-x10,y10 , "black" , linewidth = 12 )
plt.plot(-x11,y11  , "black" , linewidth = 12 )
plt.plot(-x12,y12 , "black" , linewidth = 12 )
plt.plot(-x13,y13 , "black" , linewidth = 12 )
plt.plot(-x14,y14 , "black" , linewidth = 12 )
plt.plot([1.566 , 2.4]  ,  [-2.49 , -2.49] , "black" , linewidth = 12 )
plt.plot([-1.566 , -2.4]  ,  [-2.49 , -2.49] , "black" , linewidth = 12 )
plt.plot(-x15 , y15, "black" , linewidth = 12 )

# %%
plt.figure(figsize = (15 , 5) )
plt.plot(x,y , "black" , linewidth = 12)
plt.plot(x1,y1 , "black" , linewidth = 12)
plt.plot(x2,y2, "black" , linewidth = 12)
plt.plot(x3,y3 , "black" , linewidth = 12)
plt.plot(-x4,y4, "black" , linewidth = 12)
plt.plot(x5 , y5, "black" , linewidth = 12)
plt.plot(x6 , y6, "black" , linewidth = 12)
plt.plot(x7,y7, "black" , linewidth = 12)
plt.plot(x8 , y8, "black" , linewidth = 12)
plt.plot(x9,y9, "black" , linewidth = 12)
plt.plot(x10,y10, "black" , linewidth = 12)
plt.plot(x11,y11, "black" , linewidth = 12)
plt.plot(x12,y12, "black" , linewidth = 12)
plt.plot(x13,y13, "black" , linewidth = 12)
plt.plot(x14,y14, "black" , linewidth = 12)
plt.plot(x15 , y15, "black" , linewidth = 12)
plt.plot(x16 , y16, "black" , linewidth = 12)
plt.scatter(5,-2.35 , s = 5000 ,facecolors = "gray" ,edgecolors="black" , linewidth = 10.5)
plt.plot(-x1,y1 , "black" , linewidth = 12)
plt.plot(-x2,y2 , "black" , linewidth = 12)
plt.plot(-x3,y3 , "black" , linewidth = 12)
plt.plot(-x5 , y5 , "black" , linewidth = 12)
plt.plot(-x6 , y6 , "black" , linewidth = 12)
plt.plot(-x7,y7 , "black" , linewidth = 12)
plt.plot(-x8 , y8  , "black" , linewidth = 12)
plt.plot(-x9,y9 , "black" , linewidth = 12 )
plt.plot(-x10,y10 , "black" , linewidth = 12 )
plt.plot(-x11,y11  , "black" , linewidth = 12 )
plt.plot(-x12,y12 , "black" , linewidth = 12 )
plt.plot(-x13,y13 , "black" , linewidth = 12 )
plt.plot(-x14,y14 , "black" , linewidth = 12 )
plt.plot([1.566 , 2.4]  ,  [-2.49 , -2.49] , "black" , linewidth = 12 )
plt.plot([-1.566 , -2.4]  ,  [-2.49 , -2.49] , "black" , linewidth = 12 )
plt.plot(-x15 , y15, "black" , linewidth = 12 )
plt.plot(-x16 , y16, "black" , linewidth = 12 )

# %%
plt.figure(figsize = (15 , 5) )
plt.plot(x,y , "black" , linewidth = 12)
plt.plot(x1,y1 , "black" , linewidth = 12)
plt.plot(x2,y2, "black" , linewidth = 12)
plt.plot(x3,y3 , "black" , linewidth = 12)
plt.plot(-x4,y4, "black" , linewidth = 12)
plt.plot(x5 , y5, "black" , linewidth = 12)
plt.plot(x6 , y6, "black" , linewidth = 12)
plt.plot(x7,y7, "black" , linewidth = 12)
plt.plot(x8 , y8, "black" , linewidth = 12)
plt.plot(x9,y9, "black" , linewidth = 12)
plt.plot(x10,y10, "black" , linewidth = 12)
plt.plot(x11,y11, "black" , linewidth = 12)
plt.plot(x12,y12, "black" , linewidth = 12)
plt.plot(x13,y13, "black" , linewidth = 12)
plt.plot(x14,y14, "black" , linewidth = 12)
plt.plot(x15 , y15, "black" , linewidth = 12)
plt.plot(x16 , y16, "black" , linewidth = 12)
plt.scatter(5,-2.35 , s = 5000 ,facecolors = "gray" ,edgecolors="black" , linewidth = 10.5)
plt.plot(-x1,y1 , "black" , linewidth = 12)
plt.plot(-x2,y2 , "black" , linewidth = 12)
plt.plot(-x3,y3 , "black" , linewidth = 12)
plt.plot(-x5 , y5 , "black" , linewidth = 12)
plt.plot(-x6 , y6 , "black" , linewidth = 12)
plt.plot(-x7,y7 , "black" , linewidth = 12)
plt.plot(-x8 , y8  , "black" , linewidth = 12)
plt.plot(-x9,y9 , "black" , linewidth = 12 )
plt.plot(-x10,y10 , "black" , linewidth = 12 )
plt.plot(-x11,y11  , "black" , linewidth = 12 )
plt.plot(-x12,y12 , "black" , linewidth = 12 )
plt.plot(-x13,y13 , "black" , linewidth = 12 )
plt.plot(-x14,y14 , "black" , linewidth = 12 )
plt.plot([1.566 , 2.4]  ,  [-2.49 , -2.49] , "black" , linewidth = 12 )
plt.plot([-1.566 , -2.4]  ,  [-2.49 , -2.49] , "black" , linewidth = 12 )
plt.plot(-x15 , y15, "black" , linewidth = 12 )
plt.plot(-x16 , y16, "black" , linewidth = 12 )
plt.scatter(-5,-2.35 , s = 5000 , facecolors = "gray" ,edgecolors="black" , linewidth = 10.5 )

# %%
plt.figure(figsize = (30 , 10) )
plt.plot(x,y , "black" , linewidth = 12)
plt.plot(x1,y1 , "black" , linewidth = 12)
plt.plot(x2,y2, "black" , linewidth = 12)
plt.plot(x3,y3 , "black" , linewidth = 12)
plt.plot(-x4,y4, "black" , linewidth = 12)
plt.plot(x5 , y5, "black" , linewidth = 12)
plt.plot(x6 , y6, "black" , linewidth = 12)
plt.plot(x7,y7, "black" , linewidth = 12)
plt.plot(x8 , y8, "black" , linewidth = 12)
plt.plot(x9,y9, "black" , linewidth = 12)
plt.plot(x10,y10, "black" , linewidth = 12)
plt.plot(x11,y11, "black" , linewidth = 12)
plt.plot(x12,y12, "black" , linewidth = 12)
plt.plot(x13,y13, "black" , linewidth = 12)
plt.plot(x14,y14, "black" , linewidth = 12)
plt.plot(x15 , y15, "black" , linewidth = 12)
plt.plot(x16 , y16, "black" , linewidth = 12)
plt.scatter(5,-2.35 , s = 20000 ,facecolors = "gray" ,edgecolors="black" , linewidth = 10.5)
plt.plot(-x1,y1 , "black" , linewidth = 12)
plt.plot(-x2,y2 , "black" , linewidth = 12)
plt.plot(-x3,y3 , "black" , linewidth = 12)
plt.plot(-x5 , y5 , "black" , linewidth = 12)
plt.plot(-x6 , y6 , "black" , linewidth = 12)
plt.plot(-x7,y7 , "black" , linewidth = 12)
plt.plot(-x8 , y8  , "black" , linewidth = 12)
plt.plot(-x9,y9 , "black" , linewidth = 12 )
plt.plot(-x10,y10 , "black" , linewidth = 12 )
plt.plot(-x11,y11  , "black" , linewidth = 12 )
plt.plot(-x12,y12 , "black" , linewidth = 12 )
plt.plot(-x13,y13 , "black" , linewidth = 12 )
plt.plot(-x14,y14 , "black" , linewidth = 12 )
plt.plot([1.566 , 2.4]  ,  [-2.49 , -2.49] , "black" , linewidth = 12 )
plt.plot([-1.566 , -2.4]  ,  [-2.49 , -2.49] , "black" , linewidth = 12 )
plt.plot(-x15 , y15, "black" , linewidth = 12 )
plt.plot(-x16 , y16, "black" , linewidth = 12 )
plt.scatter(-5,-2.35 , s = 20000 , facecolors = "gray" ,edgecolors="black" , linewidth = 10.5 )

plt.scatter(0,0 , s = 5000 , facecolors = "orange" ,edgecolors="red" , linewidths= 10)

# %%
y17 = np.arange(-10 , -9.5 , 0.00001)
x17 = np.sqrt((y17 + 10 )/ 0.3)


plt.figure(figsize = (20 , 10) )
plt.plot(x,y , "black" , linewidth = 12)
plt.plot(x1,y1 , "black" , linewidth = 12)
plt.plot(x2,y2, "black" , linewidth = 12)
plt.plot(x3,y3 , "black" , linewidth = 12)
plt.plot(-x4,y4, "black" , linewidth = 12)
plt.plot(x5 , y5, "black" , linewidth = 12)
plt.plot(x6 , y6, "black" , linewidth = 12)
plt.plot(x7,y7, "black" , linewidth = 12)
plt.plot(x8 , y8, "black" , linewidth = 12)
plt.plot(x9,y9, "black" , linewidth = 12)
plt.plot(x10,y10, "black" , linewidth = 12)
plt.plot(x11,y11, "black" , linewidth = 12)
plt.plot(x12,y12, "black" , linewidth = 12)
plt.plot(x13,y13, "black" , linewidth = 12)
plt.plot(x14,y14, "black" , linewidth = 12)
plt.plot(x15 , y15, "black" , linewidth = 12)
plt.plot(x16 , y16, "black" , linewidth = 12)
plt.scatter(5,-2.35 , s = 5000 ,facecolors = "gray" ,edgecolors="black" , linewidth = 10.5)
plt.plot(-x1,y1 , "black" , linewidth = 12)
plt.plot(-x2,y2 , "black" , linewidth = 12)
plt.plot(-x3,y3 , "black" , linewidth = 12)
plt.plot(-x5 , y5 , "black" , linewidth = 12)
plt.plot(-x6 , y6 , "black" , linewidth = 12)
plt.plot(-x7,y7 , "black" , linewidth = 12)
plt.plot(-x8 , y8  , "black" , linewidth = 12)
plt.plot(-x9,y9 , "black" , linewidth = 12 )
plt.plot(-x10,y10 , "black" , linewidth = 12 )
plt.plot(-x11,y11  , "black" , linewidth = 12 )
plt.plot(-x12,y12 , "black" , linewidth = 12 )
plt.plot(-x13,y13 , "black" , linewidth = 12 )
plt.plot(-x14,y14 , "black" , linewidth = 12 )
plt.plot([1.566 , 2.4]  ,  [-2.49 , -2.49] , "black" , linewidth = 12 )
plt.plot([-1.566 , -2.4]  ,  [-2.49 , -2.49] , "black" , linewidth = 12 )
plt.plot(-x15 , y15, "black" , linewidth = 12 )
plt.plot(-x16 , y16, "black" , linewidth = 12 )
plt.scatter(-5,-2.35 , s = 5000 , facecolors = "gray" ,edgecolors="black" , linewidth = 10.5 )

plt.scatter(0,0 , s = 5000 , facecolors = "orange" ,edgecolors="red" , linewidths= 10)
plt.plot(x17 , y17, "black" , linewidth = 12 )

# %%
plt.figure(figsize = (20 , 10) )
plt.plot(x,y , "black" , linewidth = 12)
plt.plot(x1,y1 , "black" , linewidth = 12)
plt.plot(x2,y2, "black" , linewidth = 12)
plt.plot(x3,y3 , "black" , linewidth = 12)
plt.plot(-x4,y4, "black" , linewidth = 12)
plt.plot(x5 , y5, "black" , linewidth = 12)
plt.plot(x6 , y6, "black" , linewidth = 12)
plt.plot(x7,y7, "black" , linewidth = 12)
plt.plot(x8 , y8, "black" , linewidth = 12)
plt.plot(x9,y9, "black" , linewidth = 12)
plt.plot(x10,y10, "black" , linewidth = 12)
plt.plot(x11,y11, "black" , linewidth = 12)
plt.plot(x12,y12, "black" , linewidth = 12)
plt.plot(x13,y13, "black" , linewidth = 12)
plt.plot(x14,y14, "black" , linewidth = 12)
plt.plot(x15 , y15, "black" , linewidth = 12)
plt.plot(x16 , y16, "black" , linewidth = 12)
plt.scatter(5,-2.35 , s = 5000 ,facecolors = "gray" ,edgecolors="black" , linewidth = 10.5)
plt.plot(-x1,y1 , "black" , linewidth = 12)
plt.plot(-x2,y2 , "black" , linewidth = 12)
plt.plot(-x3,y3 , "black" , linewidth = 12)
plt.plot(-x5 , y5 , "black" , linewidth = 12)
plt.plot(-x6 , y6 , "black" , linewidth = 12)
plt.plot(-x7,y7 , "black" , linewidth = 12)
plt.plot(-x8 , y8  , "black" , linewidth = 12)
plt.plot(-x9,y9 , "black" , linewidth = 12 )
plt.plot(-x10,y10 , "black" , linewidth = 12 )
plt.plot(-x11,y11  , "black" , linewidth = 12 )
plt.plot(-x12,y12 , "black" , linewidth = 12 )
plt.plot(-x13,y13 , "black" , linewidth = 12 )
plt.plot(-x14,y14 , "black" , linewidth = 12 )
plt.plot([1.566 , 2.4]  ,  [-2.49 , -2.49] , "black" , linewidth = 12 )
plt.plot([-1.566 , -2.4]  ,  [-2.49 , -2.49] , "black" , linewidth = 12 )
plt.plot(-x15 , y15, "black" , linewidth = 12 )
plt.plot(-x16 , y16, "black" , linewidth = 12 )
plt.scatter(-5,-2.35 , s = 5000 , facecolors = "gray" ,edgecolors="black" , linewidth = 10.5 )

plt.scatter(0,0 , s = 5000 , facecolors = "orange" ,edgecolors="red" , linewidths= 10)
plt.plot(x17 , y17, "black" , linewidth = 12 )
plt.plot(-x17 , y17, "black" , linewidth = 12 )

# %%
x18 = np.arange(-2.0 , -1.19  , 0.001)

y18 = -9.6 + 0.5 * (x18 + 1.4) * (x18 + 1.4)

plt.figure(figsize = (20 , 10) )
plt.plot(x,y , "black" , linewidth = 12)
plt.plot(x1,y1 , "black" , linewidth = 12)
plt.plot(x2,y2, "black" , linewidth = 12)
plt.plot(x3,y3 , "black" , linewidth = 12)
plt.plot(-x4,y4, "black" , linewidth = 12)
plt.plot(x5 , y5, "black" , linewidth = 12)
plt.plot(x6 , y6, "black" , linewidth = 12)
plt.plot(x7,y7, "black" , linewidth = 12)
plt.plot(x8 , y8, "black" , linewidth = 12)
plt.plot(x9,y9, "black" , linewidth = 12)
plt.plot(x10,y10, "black" , linewidth = 12)
plt.plot(x11,y11, "black" , linewidth = 12)
plt.plot(x12,y12, "black" , linewidth = 12)
plt.plot(x13,y13, "black" , linewidth = 12)
plt.plot(x14,y14, "black" , linewidth = 12)
plt.plot(x15 , y15, "black" , linewidth = 12)
plt.plot(x16 , y16, "black" , linewidth = 12)
plt.scatter(5,-2.35 , s = 5000 ,facecolors = "gray" ,edgecolors="black" , linewidth = 10.5)
plt.plot(-x1,y1 , "black" , linewidth = 12)
plt.plot(-x2,y2 , "black" , linewidth = 12)
plt.plot(-x3,y3 , "black" , linewidth = 12)
plt.plot(-x5 , y5 , "black" , linewidth = 12)
plt.plot(-x6 , y6 , "black" , linewidth = 12)
plt.plot(-x7,y7 , "black" , linewidth = 12)
plt.plot(-x8 , y8  , "black" , linewidth = 12)
plt.plot(-x9,y9 , "black" , linewidth = 12 )
plt.plot(-x10,y10 , "black" , linewidth = 12 )
plt.plot(-x11,y11  , "black" , linewidth = 12 )
plt.plot(-x12,y12 , "black" , linewidth = 12 )
plt.plot(-x13,y13 , "black" , linewidth = 12 )
plt.plot(-x14,y14 , "black" , linewidth = 12 )
plt.plot([1.566 , 2.4]  ,  [-2.49 , -2.49] , "black" , linewidth = 12 )
plt.plot([-1.566 , -2.4]  ,  [-2.49 , -2.49] , "black" , linewidth = 12 )
plt.plot(-x15 , y15, "black" , linewidth = 12 )
plt.plot(-x16 , y16, "black" , linewidth = 12 )
plt.scatter(-5,-2.35 , s = 5000 , facecolors = "gray" ,edgecolors="black" , linewidth = 10.5 )
plt.plot(x17 , y17, "black" , linewidth = 12 )
plt.plot(-x17 , y17, "black" , linewidth = 12 )
plt.scatter(0,0 , s = 5000 , facecolors = "orange" ,edgecolors="red" , linewidths= 10)
plt.plot(x18 , y18, "black" , linewidth = 12 )

# %%
plt.figure(figsize = (20 , 10) )
plt.plot(x,y , "black" , linewidth = 12)
plt.plot(x1,y1 , "black" , linewidth = 12)
plt.plot(x2,y2, "black" , linewidth = 12)
plt.plot(x3,y3 , "black" , linewidth = 12)
plt.plot(-x4,y4, "black" , linewidth = 12)
plt.plot(x5 , y5, "black" , linewidth = 12)
plt.plot(x6 , y6, "black" , linewidth = 12)
plt.plot(x7,y7, "black" , linewidth = 12)
plt.plot(x8 , y8, "black" , linewidth = 12)
plt.plot(x9,y9, "black" , linewidth = 12)
plt.plot(x10,y10, "black" , linewidth = 12)
plt.plot(x11,y11, "black" , linewidth = 12)
plt.plot(x12,y12, "black" , linewidth = 12)
plt.plot(x13,y13, "black" , linewidth = 12)
plt.plot(x14,y14, "black" , linewidth = 12)
plt.plot(x15 , y15, "black" , linewidth = 12)
plt.plot(x16 , y16, "black" , linewidth = 12)
plt.scatter(5,-2.35 , s = 5000 ,facecolors = "gray" ,edgecolors="black" , linewidth = 10.5)
plt.plot(-x1,y1 , "black" , linewidth = 12)
plt.plot(-x2,y2 , "black" , linewidth = 12)
plt.plot(-x3,y3 , "black" , linewidth = 12)
plt.plot(-x5 , y5 , "black" , linewidth = 12)
plt.plot(-x6 , y6 , "black" , linewidth = 12)
plt.plot(-x7,y7 , "black" , linewidth = 12)
plt.plot(-x8 , y8  , "black" , linewidth = 12)
plt.plot(-x9,y9 , "black" , linewidth = 12 )
plt.plot(-x10,y10 , "black" , linewidth = 12 )
plt.plot(-x11,y11  , "black" , linewidth = 12 )
plt.plot(-x12,y12 , "black" , linewidth = 12 )
plt.plot(-x13,y13 , "black" , linewidth = 12 )
plt.plot(-x14,y14 , "black" , linewidth = 12 )
plt.plot([1.566 , 2.4]  ,  [-2.49 , -2.49] , "black" , linewidth = 12 )
plt.plot([-1.566 , -2.4]  ,  [-2.49 , -2.49] , "black" , linewidth = 12 )
plt.plot(-x15 , y15, "black" , linewidth = 12 )
plt.plot(-x16 , y16, "black" , linewidth = 12 )
plt.scatter(-5,-2.35 , s = 5000 , facecolors = "gray" ,edgecolors="black" , linewidth = 10.5 )
plt.plot(x17 , y17, "black" , linewidth = 12 )
plt.plot(-x17 , y17, "black" , linewidth = 12 )
plt.scatter(0,0 , s = 5000 , facecolors = "orange" ,edgecolors="red" , linewidths= 10)
plt.plot(x18 , y18, "black" , linewidth = 12 )
plt.plot(-x18 , y18, "black" , linewidth = 12 )

# %%
x19 = np.arange(-3.15 , 3.15 , 0.0001)

y19 = 1.7 + 0.33 * x19 * x19

plt.figure(figsize = (20 , 10) )
plt.plot(x,y , "black" , linewidth = 12)
plt.plot(x1,y1 , "black" , linewidth = 12)
plt.plot(x2,y2, "black" , linewidth = 12)
plt.plot(x3,y3 , "black" , linewidth = 12)
plt.plot(-x4,y4, "black" , linewidth = 12)
plt.plot(x5 , y5, "black" , linewidth = 12)
plt.plot(x6 , y6, "black" , linewidth = 12)
plt.plot(x7,y7, "black" , linewidth = 12)
plt.plot(x8 , y8, "black" , linewidth = 12)
plt.plot(x9,y9, "black" , linewidth = 12)
plt.plot(x10,y10, "black" , linewidth = 12)
plt.plot(x11,y11, "black" , linewidth = 12)
plt.plot(x12,y12, "black" , linewidth = 12)
plt.plot(x13,y13, "black" , linewidth = 12)
plt.plot(x14,y14, "black" , linewidth = 12)
plt.plot(x15 , y15, "black" , linewidth = 12)
plt.plot(x16 , y16, "black" , linewidth = 12)
plt.scatter(5,-2.35 , s = 5000 ,facecolors = "gray" ,edgecolors="black" , linewidth = 10.5)
plt.plot(-x1,y1 , "black" , linewidth = 12)
plt.plot(-x2,y2 , "black" , linewidth = 12)
plt.plot(-x3,y3 , "black" , linewidth = 12)
plt.plot(-x5 , y5 , "black" , linewidth = 12)
plt.plot(-x6 , y6 , "black" , linewidth = 12)
plt.plot(-x7,y7 , "black" , linewidth = 12)
plt.plot(-x8 , y8  , "black" , linewidth = 12)
plt.plot(-x9,y9 , "black" , linewidth = 12 )
plt.plot(-x10,y10 , "black" , linewidth = 12 )
plt.plot(-x11,y11  , "black" , linewidth = 12 )
plt.plot(-x12,y12 , "black" , linewidth = 12 )
plt.plot(-x13,y13 , "black" , linewidth = 12 )
plt.plot(-x14,y14 , "black" , linewidth = 12 )
plt.plot([1.566 , 2.4]  ,  [-2.49 , -2.49] , "black" , linewidth = 12 )
plt.plot([-1.566 , -2.4]  ,  [-2.49 , -2.49] , "black" , linewidth = 12 )
plt.plot(-x15 , y15, "black" , linewidth = 12 )
plt.plot(-x16 , y16, "black" , linewidth = 12 )
plt.scatter(-5,-2.35 , s = 5000 , facecolors = "gray" ,edgecolors="black" , linewidth = 10.5 )
plt.plot(x17 , y17, "black" , linewidth = 12 )
plt.plot(-x17 , y17, "black" , linewidth = 12 )
plt.scatter(0,0 , s = 5000 , facecolors = "orange" ,edgecolors="red" , linewidths= 10)
plt.plot(x18 , y18, "black" , linewidth = 12 )
plt.plot(-x18 , y18, "black" , linewidth = 12 )
plt.plot(x19 , y19 , "red" , linewidth = 12)

# %%
x20 = np.arange(-3.15 , 3.15 , 0.0001)

y20 = 2.5 + 0.25 * x20 * x20

plt.figure(figsize = (20 , 10) )
plt.plot(x,y , "black" , linewidth = 12)
plt.plot(x1,y1 , "black" , linewidth = 12)
plt.plot(x2,y2, "black" , linewidth = 12)
plt.plot(x3,y3 , "black" , linewidth = 12)
plt.plot(-x4,y4, "black" , linewidth = 12)
plt.plot(x5 , y5, "black" , linewidth = 12)
plt.plot(x6 , y6, "black" , linewidth = 12)
plt.plot(x7,y7, "black" , linewidth = 12)
plt.plot(x8 , y8, "black" , linewidth = 12)
plt.plot(x9,y9, "black" , linewidth = 12)
plt.plot(x10,y10, "black" , linewidth = 12)
plt.plot(x11,y11, "black" , linewidth = 12)
plt.plot(x12,y12, "black" , linewidth = 12)
plt.plot(x13,y13, "black" , linewidth = 12)
plt.plot(x14,y14, "black" , linewidth = 12)
plt.plot(x15 , y15, "black" , linewidth = 12)
plt.plot(x16 , y16, "black" , linewidth = 12)
plt.scatter(5,-2.35 , s = 5000 ,facecolors = "gray" ,edgecolors="black" , linewidth = 10.5)
plt.plot(-x1,y1 , "black" , linewidth = 12)
plt.plot(-x2,y2 , "black" , linewidth = 12)
plt.plot(-x3,y3 , "black" , linewidth = 12)
plt.plot(-x5 , y5 , "black" , linewidth = 12)
plt.plot(-x6 , y6 , "black" , linewidth = 12)
plt.plot(-x7,y7 , "black" , linewidth = 12)
plt.plot(-x8 , y8  , "black" , linewidth = 12)
plt.plot(-x9,y9 , "black" , linewidth = 12 )
plt.plot(-x10,y10 , "black" , linewidth = 12 )
plt.plot(-x11,y11  , "black" , linewidth = 12 )
plt.plot(-x12,y12 , "black" , linewidth = 12 )
plt.plot(-x13,y13 , "black" , linewidth = 12 )
plt.plot(-x14,y14 , "black" , linewidth = 12 )
plt.plot([1.566 , 2.4]  ,  [-2.49 , -2.49] , "black" , linewidth = 12 )
plt.plot([-1.566 , -2.4]  ,  [-2.49 , -2.49] , "black" , linewidth = 12 )
plt.plot(-x15 , y15, "black" , linewidth = 12 )
plt.plot(-x16 , y16, "black" , linewidth = 12 )
plt.scatter(-5,-2.35 , s = 5000 , facecolors = "gray" ,edgecolors="black" , linewidth = 10.5 )
plt.plot(x17 , y17, "black" , linewidth = 12 )
plt.plot(-x17 , y17, "black" , linewidth = 12 )
plt.scatter(0,0 , s = 5000 , facecolors = "orange" ,edgecolors="red" , linewidths= 10)
plt.plot(x18 , y18, "black" , linewidth = 12 )
plt.plot(-x18 , y18, "black" , linewidth = 12 )
plt.plot(x19 , y19 , "red" , linewidth = 12)
plt.plot(x20 , y20 , "red" , linewidth = 12)

# %%
x21 = np.arange(-2, 2, 0.001)

y21 = -11 + 0.3* np.sin(1.5*x21 - 1.5)

plt.figure(figsize = (20 , 15) )
plt.plot(x,y , "black" , linewidth = 12)
plt.plot(x1,y1 , "black" , linewidth = 12)
plt.plot(x2,y2, "black" , linewidth = 12)
plt.plot(x3,y3 , "black" , linewidth = 12)
plt.plot(-x4,y4, "black" , linewidth = 12)
plt.plot(x5 , y5, "black" , linewidth = 12)
plt.plot(x6 , y6, "black" , linewidth = 12)
plt.plot(x7,y7, "black" , linewidth = 12)
plt.plot(x8 , y8, "black" , linewidth = 12)
plt.plot(x9,y9, "black" , linewidth = 12)
plt.plot(x10,y10, "black" , linewidth = 12)
plt.plot(x11,y11, "black" , linewidth = 12)
plt.plot(x12,y12, "black" , linewidth = 12)
plt.plot(x13,y13, "black" , linewidth = 12)
plt.plot(x14,y14, "black" , linewidth = 12)
plt.plot(x15 , y15, "black" , linewidth = 12)
plt.plot(x16 , y16, "black" , linewidth = 12)
plt.scatter(5,-2.35 , s = 10000 ,facecolors = "gray" ,edgecolors="black" , linewidth = 10.5)
plt.plot(-x1,y1 , "black" , linewidth = 12)
plt.plot(-x2,y2 , "black" , linewidth = 12)
plt.plot(-x3,y3 , "black" , linewidth = 12)
plt.plot(-x5 , y5 , "black" , linewidth = 12)
plt.plot(-x6 , y6 , "black" , linewidth = 12)
plt.plot(-x7,y7 , "black" , linewidth = 12)
plt.plot(-x8 , y8  , "black" , linewidth = 12)
plt.plot(-x9,y9 , "black" , linewidth = 12 )
plt.plot(-x10,y10 , "black" , linewidth = 12 )
plt.plot(-x11,y11  , "black" , linewidth = 12 )
plt.plot(-x12,y12 , "black" , linewidth = 12 )
plt.plot(-x13,y13 , "black" , linewidth = 12 )
plt.plot(-x14,y14 , "black" , linewidth = 12 )
plt.plot([1.566 , 2.4]  ,  [-2.49 , -2.49] , "black" , linewidth = 12 )
plt.plot([-1.566 , -2.4]  ,  [-2.49 , -2.49] , "black" , linewidth = 12 )
plt.plot(-x15 , y15, "black" , linewidth = 12 )
plt.plot(-x16 , y16, "black" , linewidth = 12 )
plt.scatter(-5,-2.35 , s = 10000 , facecolors = "gray" ,edgecolors="black" , linewidth = 10.5 )
plt.plot(x17 , y17, "black" , linewidth = 12 )
plt.plot(-x17 , y17, "black" , linewidth = 12 )
plt.scatter(0,0 , s = 5000 , facecolors = "orange" ,edgecolors="red" , linewidths= 10)
plt.plot(x18 , y18, "black" , linewidth = 12 )
plt.plot(-x18 , y18, "black" , linewidth = 12 )
plt.plot(x19 , y19 , "red" , linewidth = 12)
plt.plot(x20 , y20 , "red" , linewidth = 12)
plt.plot(x21 , y21, "red" , linewidth = 12)

# %%
x22 = np.arange(2, 3.17, 0.001)

y22 = -10.40 + 0.3* np.sin(1.8*x22 + 1.0)

plt.figure(figsize = (20 , 15) )
plt.plot(x,y , "black" , linewidth = 12)
plt.plot(x1,y1 , "black" , linewidth = 12)
plt.plot(x2,y2, "black" , linewidth = 12)
plt.plot(x3,y3 , "black" , linewidth = 12)
plt.plot(-x4,y4, "black" , linewidth = 12)
plt.plot(x5 , y5, "black" , linewidth = 12)
plt.plot(x6 , y6, "black" , linewidth = 12)
plt.plot(x7,y7, "black" , linewidth = 12)
plt.plot(x8 , y8, "black" , linewidth = 12)
plt.plot(x9,y9, "black" , linewidth = 12)
plt.plot(x10,y10, "black" , linewidth = 12)
plt.plot(x11,y11, "black" , linewidth = 12)
plt.plot(x12,y12, "black" , linewidth = 12)
plt.plot(x13,y13, "black" , linewidth = 12)
plt.plot(x14,y14, "black" , linewidth = 12)
plt.plot(x15 , y15, "black" , linewidth = 12)
plt.plot(x16 , y16, "black" , linewidth = 12)
plt.scatter(5,-2.35 , s = 10000 ,facecolors = "gray" ,edgecolors="black" , linewidth = 10.5)
plt.plot(-x1,y1 , "black" , linewidth = 12)
plt.plot(-x2,y2 , "black" , linewidth = 12)
plt.plot(-x3,y3 , "black" , linewidth = 12)
plt.plot(-x5 , y5 , "black" , linewidth = 12)
plt.plot(-x6 , y6 , "black" , linewidth = 12)
plt.plot(-x7,y7 , "black" , linewidth = 12)
plt.plot(-x8 , y8  , "black" , linewidth = 12)
plt.plot(-x9,y9 , "black" , linewidth = 12 )
plt.plot(-x10,y10 , "black" , linewidth = 12 )
plt.plot(-x11,y11  , "black" , linewidth = 12 )
plt.plot(-x12,y12 , "black" , linewidth = 12 )
plt.plot(-x13,y13 , "black" , linewidth = 12 )
plt.plot(-x14,y14 , "black" , linewidth = 12 )
plt.plot([1.566 , 2.4]  ,  [-2.49 , -2.49] , "black" , linewidth = 12 )
plt.plot([-1.566 , -2.4]  ,  [-2.49 , -2.49] , "black" , linewidth = 12 )
plt.plot(-x15 , y15, "black" , linewidth = 12 )
plt.plot(-x16 , y16, "black" , linewidth = 12 )
plt.scatter(-5,-2.35 , s = 10000 , facecolors = "gray" ,edgecolors="black" , linewidth = 10.5 )
plt.plot(x17 , y17, "black" , linewidth = 12 )
plt.plot(-x17 , y17, "black" , linewidth = 12 )
plt.scatter(0,0 , s = 5000 , facecolors = "orange" ,edgecolors="red" , linewidths= 10)
plt.plot(x18 , y18, "black" , linewidth = 12 )
plt.plot(-x18 , y18, "black" , linewidth = 12 )
plt.plot(x19 , y19 , "red" , linewidth = 12)
plt.plot(x20 , y20 , "red" , linewidth = 12)
plt.plot(x21 , y21, "red" , linewidth = 12)
plt.plot(x22 , y22 , "red" , linewidth = 12)

# %%
plt.figure(figsize = (20 , 15) )
plt.plot(x,y , "black" , linewidth = 12)
plt.plot(x1,y1 , "black" , linewidth = 12)
plt.plot(x2,y2, "black" , linewidth = 12)
plt.plot(x3,y3 , "black" , linewidth = 12)
plt.plot(-x4,y4, "black" , linewidth = 12)
plt.plot(x5 , y5, "black" , linewidth = 12)
plt.plot(x6 , y6, "black" , linewidth = 12)
plt.plot(x7,y7, "black" , linewidth = 12)
plt.plot(x8 , y8, "black" , linewidth = 12)
plt.plot(x9,y9, "black" , linewidth = 12)
plt.plot(x10,y10, "black" , linewidth = 12)
plt.plot(x11,y11, "black" , linewidth = 12)
plt.plot(x12,y12, "black" , linewidth = 12)
plt.plot(x13,y13, "black" , linewidth = 12)
plt.plot(x14,y14, "black" , linewidth = 12)
plt.plot(x15 , y15, "black" , linewidth = 12)
plt.plot(x16 , y16, "black" , linewidth = 12)
plt.scatter(5,-2.35 , s = 10000 ,facecolors = "gray" ,edgecolors="black" , linewidth = 10.5)
plt.plot(-x1,y1 , "black" , linewidth = 12)
plt.plot(-x2,y2 , "black" , linewidth = 12)
plt.plot(-x3,y3 , "black" , linewidth = 12)
plt.plot(-x5 , y5 , "black" , linewidth = 12)
plt.plot(-x6 , y6 , "black" , linewidth = 12)
plt.plot(-x7,y7 , "black" , linewidth = 12)
plt.plot(-x8 , y8  , "black" , linewidth = 12)
plt.plot(-x9,y9 , "black" , linewidth = 12 )
plt.plot(-x10,y10 , "black" , linewidth = 12 )
plt.plot(-x11,y11  , "black" , linewidth = 12 )
plt.plot(-x12,y12 , "black" , linewidth = 12 )
plt.plot(-x13,y13 , "black" , linewidth = 12 )
plt.plot(-x14,y14 , "black" , linewidth = 12 )
plt.plot([1.566 , 2.4]  ,  [-2.49 , -2.49] , "black" , linewidth = 12 )
plt.plot([-1.566 , -2.4]  ,  [-2.49 , -2.49] , "black" , linewidth = 12 )
plt.plot(-x15 , y15, "black" , linewidth = 12 )
plt.plot(-x16 , y16, "black" , linewidth = 12 )
plt.scatter(-5,-2.35 , s = 10000 , facecolors = "gray" ,edgecolors="black" , linewidth = 10.5 )
plt.plot(x17 , y17, "black" , linewidth = 12 )
plt.plot(-x17 , y17, "black" , linewidth = 12 )
plt.scatter(0,0 , s = 5000 , facecolors = "orange" ,edgecolors="red" , linewidths= 10)
plt.plot(x18 , y18, "black" , linewidth = 12 )
plt.plot(-x18 , y18, "black" , linewidth = 12 )
plt.plot(x19 , y19 , "red" , linewidth = 12)
plt.plot(x20 , y20 , "red" , linewidth = 12)
plt.plot(x21 , y21, "red" , linewidth = 12)
plt.plot(x22 , y22 , "red" , linewidth = 12)
plt.plot(-x22 , y22 , "red" , linewidth = 12)

# %%
x23 = np.arange(3.17 , 3.25 , 0.0001)
y23 =  (- 10* x23) + 21.45


plt.figure(figsize = (20 , 15) )
plt.plot(x,y , "black" , linewidth = 12)
plt.plot(x1,y1 , "black" , linewidth = 12)
plt.plot(x2,y2, "black" , linewidth = 12)
plt.plot(x3,y3 , "black" , linewidth = 12)
plt.plot(-x4,y4, "black" , linewidth = 12)
plt.plot(x5 , y5, "black" , linewidth = 12)
plt.plot(x6 , y6, "black" , linewidth = 12)
plt.plot(x7,y7, "black" , linewidth = 12)
plt.plot(x8 , y8, "black" , linewidth = 12)
plt.plot(x9,y9, "black" , linewidth = 12)
plt.plot(x10,y10, "black" , linewidth = 12)
plt.plot(x11,y11, "black" , linewidth = 12)
plt.plot(x12,y12, "black" , linewidth = 12)
plt.plot(x13,y13, "black" , linewidth = 12)
plt.plot(x14,y14, "black" , linewidth = 12)
plt.plot(x15 , y15, "black" , linewidth = 12)
plt.plot(x16 , y16, "black" , linewidth = 12)
plt.scatter(5,-2.35 , s = 10000 ,facecolors = "gray" ,edgecolors="black" , linewidth = 10.5)
plt.plot(-x1,y1 , "black" , linewidth = 12)
plt.plot(-x2,y2 , "black" , linewidth = 12)
plt.plot(-x3,y3 , "black" , linewidth = 12)
plt.plot(-x5 , y5 , "black" , linewidth = 12)
plt.plot(-x6 , y6 , "black" , linewidth = 12)
plt.plot(-x7,y7 , "black" , linewidth = 12)
plt.plot(-x8 , y8  , "black" , linewidth = 12)
plt.plot(-x9,y9 , "black" , linewidth = 12 )
plt.plot(-x10,y10 , "black" , linewidth = 12 )
plt.plot(-x11,y11  , "black" , linewidth = 12 )
plt.plot(-x12,y12 , "black" , linewidth = 12 )
plt.plot(-x13,y13 , "black" , linewidth = 12 )
plt.plot(-x14,y14 , "black" , linewidth = 12 )
plt.plot([1.566 , 2.4]  ,  [-2.49 , -2.49] , "black" , linewidth = 12 )
plt.plot([-1.566 , -2.4]  ,  [-2.49 , -2.49] , "black" , linewidth = 12 )
plt.plot(-x15 , y15, "black" , linewidth = 12 )
plt.plot(-x16 , y16, "black" , linewidth = 12 )
plt.scatter(-5,-2.35 , s = 10000 , facecolors = "gray" ,edgecolors="black" , linewidth = 10.5 )
plt.plot(x17 , y17, "black" , linewidth = 12 )
plt.plot(-x17 , y17, "black" , linewidth = 12 )
plt.scatter(0,0 , s = 5000 , facecolors = "orange" ,edgecolors="red" , linewidths= 10)
plt.plot(x18 , y18, "black" , linewidth = 12 )
plt.plot(-x18 , y18, "black" , linewidth = 12 )
plt.plot(x19 , y19 , "red" , linewidth = 12)
plt.plot(x20 , y20 , "red" , linewidth = 12)
plt.plot(x21 , y21, "red" , linewidth = 12)
plt.plot(x22 , y22 , "red" , linewidth = 12)
plt.plot(-x22 , y22 , "red" , linewidth = 12)
plt.plot(x23 , y23 , "red" , linewidth = 12)

# %%
plt.figure(figsize = (20 , 15) )
plt.plot(x,y , "black" , linewidth = 12)
plt.plot(x1,y1 , "black" , linewidth = 12)
plt.plot(x2,y2, "black" , linewidth = 12)
plt.plot(x3,y3 , "black" , linewidth = 12)
plt.plot(-x4,y4, "black" , linewidth = 12)
plt.plot(x5 , y5, "black" , linewidth = 12)
plt.plot(x6 , y6, "black" , linewidth = 12)
plt.plot(x7,y7, "black" , linewidth = 12)
plt.plot(x8 , y8, "black" , linewidth = 12)
plt.plot(x9,y9, "black" , linewidth = 12)
plt.plot(x10,y10, "black" , linewidth = 12)
plt.plot(x11,y11, "black" , linewidth = 12)
plt.plot(x12,y12, "black" , linewidth = 12)
plt.plot(x13,y13, "black" , linewidth = 12)
plt.plot(x14,y14, "black" , linewidth = 12)
plt.plot(x15 , y15, "black" , linewidth = 12)
plt.plot(x16 , y16, "black" , linewidth = 12)
plt.scatter(5,-2.35 , s = 10000 ,facecolors = "gray" ,edgecolors="black" , linewidth = 10.5)
plt.plot(-x1,y1 , "black" , linewidth = 12)
plt.plot(-x2,y2 , "black" , linewidth = 12)
plt.plot(-x3,y3 , "black" , linewidth = 12)
plt.plot(-x5 , y5 , "black" , linewidth = 12)
plt.plot(-x6 , y6 , "black" , linewidth = 12)
plt.plot(-x7,y7 , "black" , linewidth = 12)
plt.plot(-x8 , y8  , "black" , linewidth = 12)
plt.plot(-x9,y9 , "black" , linewidth = 12 )
plt.plot(-x10,y10 , "black" , linewidth = 12 )
plt.plot(-x11,y11  , "black" , linewidth = 12 )
plt.plot(-x12,y12 , "black" , linewidth = 12 )
plt.plot(-x13,y13 , "black" , linewidth = 12 )
plt.plot(-x14,y14 , "black" , linewidth = 12 )
plt.plot([1.566 , 2.4]  ,  [-2.49 , -2.49] , "black" , linewidth = 12 )
plt.plot([-1.566 , -2.4]  ,  [-2.49 , -2.49] , "black" , linewidth = 12 )
plt.plot(-x15 , y15, "black" , linewidth = 12 )
plt.plot(-x16 , y16, "black" , linewidth = 12 )
plt.scatter(-5,-2.35 , s = 10000 , facecolors = "gray" ,edgecolors="black" , linewidth = 10.5 )
plt.plot(x17 , y17, "black" , linewidth = 12 )
plt.plot(-x17 , y17, "black" , linewidth = 12 )
plt.scatter(0,0 , s = 5000 , facecolors = "orange" ,edgecolors="red" , linewidths= 10)
plt.plot(x18 , y18, "black" , linewidth = 12 )
plt.plot(-x18 , y18, "black" , linewidth = 12 )
plt.plot(x19 , y19 , "red" , linewidth = 12)
plt.plot(x20 , y20 , "red" , linewidth = 12)
plt.plot(x21 , y21, "red" , linewidth = 12)
plt.plot(x22 , y22 , "red" , linewidth = 12)
plt.plot(-x22 , y22 , "red" , linewidth = 12)
plt.plot(x23 , y23 , "red" , linewidth = 12)
plt.plot(-x23 , y23 , "red" , linewidth = 12)

# %%
x24 = np.arange(-3.17, 3.17, 0.001)

y24 = -11.5 + 0.5* np.sin(0.8*x24 - 1.5)

plt.figure(figsize = (20 , 15) )
plt.plot(x,y , "black" , linewidth = 12)
plt.plot(x1,y1 , "black" , linewidth = 12)
plt.plot(x2,y2, "black" , linewidth = 12)
plt.plot(x3,y3 , "black" , linewidth = 12)
plt.plot(-x4,y4, "black" , linewidth = 12)
plt.plot(x5 , y5, "black" , linewidth = 12)
plt.plot(x6 , y6, "black" , linewidth = 12)
plt.plot(x7,y7, "black" , linewidth = 12)
plt.plot(x8 , y8, "black" , linewidth = 12)
plt.plot(x9,y9, "black" , linewidth = 12)
plt.plot(x10,y10, "black" , linewidth = 12)
plt.plot(x11,y11, "black" , linewidth = 12)
plt.plot(x12,y12, "black" , linewidth = 12)
plt.plot(x13,y13, "black" , linewidth = 12)
plt.plot(x14,y14, "black" , linewidth = 12)
plt.plot(x15 , y15, "black" , linewidth = 12)
plt.plot(x16 , y16, "black" , linewidth = 12)
plt.scatter(5,-2.35 , s = 10000 ,facecolors = "gray" ,edgecolors="black" , linewidth = 10.5)
plt.plot(-x1,y1 , "black" , linewidth = 12)
plt.plot(-x2,y2 , "black" , linewidth = 12)
plt.plot(-x3,y3 , "black" , linewidth = 12)
plt.plot(-x5 , y5 , "black" , linewidth = 12)
plt.plot(-x6 , y6 , "black" , linewidth = 12)
plt.plot(-x7,y7 , "black" , linewidth = 12)
plt.plot(-x8 , y8  , "black" , linewidth = 12)
plt.plot(-x9,y9 , "black" , linewidth = 12 )
plt.plot(-x10,y10 , "black" , linewidth = 12 )
plt.plot(-x11,y11  , "black" , linewidth = 12 )
plt.plot(-x12,y12 , "black" , linewidth = 12 )
plt.plot(-x13,y13 , "black" , linewidth = 12 )
plt.plot(-x14,y14 , "black" , linewidth = 12 )
plt.plot([1.566 , 2.4]  ,  [-2.49 , -2.49] , "black" , linewidth = 12 )
plt.plot([-1.566 , -2.4]  ,  [-2.49 , -2.49] , "black" , linewidth = 12 )
plt.plot(-x15 , y15, "black" , linewidth = 12 )
plt.plot(-x16 , y16, "black" , linewidth = 12 )
plt.scatter(-5,-2.35 , s = 10000 , facecolors = "gray" ,edgecolors="black" , linewidth = 10.5 )
plt.plot(x17 , y17, "black" , linewidth = 12 )
plt.plot(-x17 , y17, "black" , linewidth = 12 )
plt.scatter(0,0 , s = 5000 , facecolors = "orange" ,edgecolors="red" , linewidths= 10)
plt.plot(x18 , y18, "black" , linewidth = 12 )
plt.plot(-x18 , y18, "black" , linewidth = 12 )
plt.plot(x19 , y19 , "red" , linewidth = 12)
plt.plot(x20 , y20 , "red" , linewidth = 12)
plt.plot(x21 , y21, "red" , linewidth = 12)
plt.plot(x22 , y22 , "red" , linewidth = 12)
plt.plot(-x22 , y22 , "red" , linewidth = 12)
plt.plot(x23 , y23 , "red" , linewidth = 12)
plt.plot(-x23 , y23 , "red" , linewidth = 12)
plt.plot(x24 , y24 , "red"  ,linewidth  = 12)

# %%
x25 = np.arange(-2.588 , 2.588 , 0.0001)

y25 = -12.9 + 0.24 * x25 * x25

plt.figure(figsize = (20 , 15) )
plt.plot(x,y , "black" , linewidth = 12)
plt.plot(x1,y1 , "black" , linewidth = 12)
plt.plot(x2,y2, "black" , linewidth = 12)
plt.plot(x3,y3 , "black" , linewidth = 12)
plt.plot(-x4,y4, "black" , linewidth = 12)
plt.plot(x5 , y5, "black" , linewidth = 12)
plt.plot(x6 , y6, "black" , linewidth = 12)
plt.plot(x7,y7, "black" , linewidth = 12)
plt.plot(x8 , y8, "black" , linewidth = 12)
plt.plot(x9,y9, "black" , linewidth = 12)
plt.plot(x10,y10, "black" , linewidth = 12)
plt.plot(x11,y11, "black" , linewidth = 12)
plt.plot(x12,y12, "black" , linewidth = 12)
plt.plot(x13,y13, "black" , linewidth = 12)
plt.plot(x14,y14, "black" , linewidth = 12)
plt.plot(x15 , y15, "black" , linewidth = 12)
plt.plot(x16 , y16, "black" , linewidth = 12)
plt.scatter(5,-2.35 , s = 10000 ,facecolors = "gray" ,edgecolors="black" , linewidth = 10.5)
plt.plot(-x1,y1 , "black" , linewidth = 12)
plt.plot(-x2,y2 , "black" , linewidth = 12)
plt.plot(-x3,y3 , "black" , linewidth = 12)
plt.plot(-x5 , y5 , "black" , linewidth = 12)
plt.plot(-x6 , y6 , "black" , linewidth = 12)
plt.plot(-x7,y7 , "black" , linewidth = 12)
plt.plot(-x8 , y8  , "black" , linewidth = 12)
plt.plot(-x9,y9 , "black" , linewidth = 12 )
plt.plot(-x10,y10 , "black" , linewidth = 12 )
plt.plot(-x11,y11  , "black" , linewidth = 12 )
plt.plot(-x12,y12 , "black" , linewidth = 12 )
plt.plot(-x13,y13 , "black" , linewidth = 12 )
plt.plot(-x14,y14 , "black" , linewidth = 12 )
plt.plot([1.566 , 2.4]  ,  [-2.49 , -2.49] , "black" , linewidth = 12 )
plt.plot([-1.566 , -2.4]  ,  [-2.49 , -2.49] , "black" , linewidth = 12 )
plt.plot(-x15 , y15, "black" , linewidth = 12 )
plt.plot(-x16 , y16, "black" , linewidth = 12 )
plt.scatter(-5,-2.35 , s = 10000 , facecolors = "gray" ,edgecolors="black" , linewidth = 10.5 )
plt.plot(x17 , y17, "black" , linewidth = 12 )
plt.plot(-x17 , y17, "black" , linewidth = 12 )
plt.scatter(0,0 , s = 5000 , facecolors = "orange" ,edgecolors="red" , linewidths= 10)
plt.plot(x18 , y18, "black" , linewidth = 12 )
plt.plot(-x18 , y18, "black" , linewidth = 12 )
plt.plot(x19 , y19 , "red" , linewidth = 12)
plt.plot(x20 , y20 , "red" , linewidth = 12)
plt.plot(x21 , y21, "red" , linewidth = 12)
plt.plot(x22 , y22 , "red" , linewidth = 12)
plt.plot(-x22 , y22 , "red" , linewidth = 12)
plt.plot(x23 , y23 , "red" , linewidth = 12)
plt.plot(-x23 , y23 , "red" , linewidth = 12)
plt.plot(x24 , y24 , "red"  ,linewidth  = 12)
plt.plot(x25 , y25 , "red" , linewidth = 12)

# %%
x26 = np.arange(-1.4 , 1.4 ,0.00001)
y26 = 3.32+ 0.97 * x26 * x26

plt.figure(figsize = (20 , 15) )
plt.plot(x,y , "black" , linewidth = 12)
plt.plot(x1,y1 , "black" , linewidth = 12)
plt.plot(x2,y2, "black" , linewidth = 12)
plt.plot(x3,y3 , "black" , linewidth = 12)
plt.plot(-x4,y4, "black" , linewidth = 12)
plt.plot(x5 , y5, "black" , linewidth = 12)
plt.plot(x6 , y6, "black" , linewidth = 12)
plt.plot(x7,y7, "black" , linewidth = 12)
plt.plot(x8 , y8, "black" , linewidth = 12)
plt.plot(x9,y9, "black" , linewidth = 12)
plt.plot(x10,y10, "black" , linewidth = 12)
plt.plot(x11,y11, "black" , linewidth = 12)
plt.plot(x12,y12, "black" , linewidth = 12)
plt.plot(x13,y13, "black" , linewidth = 12)
plt.plot(x14,y14, "black" , linewidth = 12)
plt.plot(x15 , y15, "black" , linewidth = 12)
plt.plot(x16 , y16, "black" , linewidth = 12)
plt.scatter(5,-2.35 , s = 10000 ,facecolors = "gray" ,edgecolors="black" , linewidth = 10.5)
plt.plot(-x1,y1 , "black" , linewidth = 12)
plt.plot(-x2,y2 , "black" , linewidth = 12)
plt.plot(-x3,y3 , "black" , linewidth = 12)
plt.plot(-x5 , y5 , "black" , linewidth = 12)
plt.plot(-x6 , y6 , "black" , linewidth = 12)
plt.plot(-x7,y7 , "black" , linewidth = 12)
plt.plot(-x8 , y8  , "black" , linewidth = 12)
plt.plot(-x9,y9 , "black" , linewidth = 12 )
plt.plot(-x10,y10 , "black" , linewidth = 12 )
plt.plot(-x11,y11  , "black" , linewidth = 12 )
plt.plot(-x12,y12 , "black" , linewidth = 12 )
plt.plot(-x13,y13 , "black" , linewidth = 12 )
plt.plot(-x14,y14 , "black" , linewidth = 12 )
plt.plot([1.566 , 2.4]  ,  [-2.49 , -2.49] , "black" , linewidth = 12 )
plt.plot([-1.566 , -2.4]  ,  [-2.49 , -2.49] , "black" , linewidth = 12 )
plt.plot(-x15 , y15, "black" , linewidth = 12 )
plt.plot(-x16 , y16, "black" , linewidth = 12 )
plt.scatter(-5,-2.35 , s = 10000 , facecolors = "gray" ,edgecolors="black" , linewidth = 10.5 )
plt.plot(x17 , y17, "black" , linewidth = 12 )
plt.plot(-x17 , y17, "black" , linewidth = 12 )
plt.scatter(0,0 , s = 5000 , facecolors = "orange" ,edgecolors="red" , linewidths= 10)
plt.plot(x18 , y18, "black" , linewidth = 12 )
plt.plot(-x18 , y18, "black" , linewidth = 12 )
plt.plot(x19 , y19 , "red" , linewidth = 12)
plt.plot(x20 , y20 , "red" , linewidth = 12)
plt.plot(x21 , y21, "red" , linewidth = 12)
plt.plot(x22 , y22 , "red" , linewidth = 12)
plt.plot(-x22 , y22 , "red" , linewidth = 12)
plt.plot(x23 , y23 , "red" , linewidth = 12)
plt.plot(-x23 , y23 , "red" , linewidth = 12)
plt.plot(x24 , y24 , "red"  ,linewidth  = 12)
plt.plot(x25 , y25 , "red" , linewidth = 12)
plt.plot(x26 , y26 , "red" , linewidth = 12)

# %%
x27 = np.arange(-1.4 ,0 ,0.00001)


y27 = 4.1277142857142857142857142857143 * x27 + 11

plt.figure(figsize = (20 , 20) )
plt.plot(x,y , "black" , linewidth = 12)
plt.plot(x1,y1 , "black" , linewidth = 12)
plt.plot(x2,y2, "black" , linewidth = 12)
plt.plot(x3,y3 , "black" , linewidth = 12)
plt.plot(-x4,y4, "black" , linewidth = 12)
plt.plot(x5 , y5, "black" , linewidth = 12)
plt.plot(x6 , y6, "black" , linewidth = 12)
plt.plot(x7,y7, "black" , linewidth = 12)
plt.plot(x8 , y8, "black" , linewidth = 12)
plt.plot(x9,y9, "black" , linewidth = 12)
plt.plot(x10,y10, "black" , linewidth = 12)
plt.plot(x11,y11, "black" , linewidth = 12)
plt.plot(x12,y12, "black" , linewidth = 12)
plt.plot(x13,y13, "black" , linewidth = 12)
plt.plot(x14,y14, "black" , linewidth = 12)
plt.plot(x15 , y15, "black" , linewidth = 12)
plt.plot(x16 , y16, "black" , linewidth = 12)
plt.scatter(5,-2.35 , s = 10000 ,facecolors = "gray" ,edgecolors="black" , linewidth = 10.5)
plt.plot(-x1,y1 , "black" , linewidth = 12)
plt.plot(-x2,y2 , "black" , linewidth = 12)
plt.plot(-x3,y3 , "black" , linewidth = 12)
plt.plot(-x5 , y5 , "black" , linewidth = 12)
plt.plot(-x6 , y6 , "black" , linewidth = 12)
plt.plot(-x7,y7 , "black" , linewidth = 12)
plt.plot(-x8 , y8  , "black" , linewidth = 12)
plt.plot(-x9,y9 , "black" , linewidth = 12 )
plt.plot(-x10,y10 , "black" , linewidth = 12 )
plt.plot(-x11,y11  , "black" , linewidth = 12 )
plt.plot(-x12,y12 , "black" , linewidth = 12 )
plt.plot(-x13,y13 , "black" , linewidth = 12 )
plt.plot(-x14,y14 , "black" , linewidth = 12 )
plt.plot([1.566 , 2.4]  ,  [-2.49 , -2.49] , "black" , linewidth = 12 )
plt.plot([-1.566 , -2.4]  ,  [-2.49 , -2.49] , "black" , linewidth = 12 )
plt.plot(-x15 , y15, "black" , linewidth = 12 )
plt.plot(-x16 , y16, "black" , linewidth = 12 )
plt.scatter(-5,-2.35 , s = 10000 , facecolors = "gray" ,edgecolors="black" , linewidth = 10.5 )
plt.plot(x17 , y17, "black" , linewidth = 12 )
plt.plot(-x17 , y17, "black" , linewidth = 12 )
plt.scatter(0,0 , s = 5000 , facecolors = "orange" ,edgecolors="red" , linewidths= 10)
plt.plot(x18 , y18, "black" , linewidth = 12 )
plt.plot(-x18 , y18, "black" , linewidth = 12 )
plt.plot(x19 , y19 , "red" , linewidth = 12)
plt.plot(x20 , y20 , "red" , linewidth = 12)
plt.plot(x21 , y21, "red" , linewidth = 12)
plt.plot(x22 , y22 , "red" , linewidth = 12)
plt.plot(-x22 , y22 , "red" , linewidth = 12)
plt.plot(x23 , y23 , "red" , linewidth = 12)
plt.plot(-x23 , y23 , "red" , linewidth = 12)
plt.plot(x24 , y24 , "red"  ,linewidth  = 12)
plt.plot(x25 , y25 , "red" , linewidth = 12)
plt.plot(x26 , y26 , "red" , linewidth = 12)
plt.plot(x27 , y27 , "red" , linewidth = 12)

# %%
x28 = np.arange(1.4 ,0 ,-0.00001)


y28 = (-4.1277142857142857142857142857143 * x28) + 11

plt.figure(figsize = (20 , 20) )
plt.plot(x,y , "black" , linewidth = 12)
plt.plot(x1,y1 , "black" , linewidth = 12)
plt.plot(x2,y2, "black" , linewidth = 12)
plt.plot(x3,y3 , "black" , linewidth = 12)
plt.plot(-x4,y4, "black" , linewidth = 12)
plt.plot(x5 , y5, "black" , linewidth = 12)
plt.plot(x6 , y6, "black" , linewidth = 12)
plt.plot(x7,y7, "black" , linewidth = 12)
plt.plot(x8 , y8, "black" , linewidth = 12)
plt.plot(x9,y9, "black" , linewidth = 12)
plt.plot(x10,y10, "black" , linewidth = 12)
plt.plot(x11,y11, "black" , linewidth = 12)
plt.plot(x12,y12, "black" , linewidth = 12)
plt.plot(x13,y13, "black" , linewidth = 12)
plt.plot(x14,y14, "black" , linewidth = 12)
plt.plot(x15 , y15, "black" , linewidth = 12)
plt.plot(x16 , y16, "black" , linewidth = 12)
plt.scatter(5,-2.35 , s = 10000 ,facecolors = "gray" ,edgecolors="black" , linewidth = 10.5)
plt.plot(-x1,y1 , "black" , linewidth = 12)
plt.plot(-x2,y2 , "black" , linewidth = 12)
plt.plot(-x3,y3 , "black" , linewidth = 12)
plt.plot(-x5 , y5 , "black" , linewidth = 12)
plt.plot(-x6 , y6 , "black" , linewidth = 12)
plt.plot(-x7,y7 , "black" , linewidth = 12)
plt.plot(-x8 , y8  , "black" , linewidth = 12)
plt.plot(-x9,y9 , "black" , linewidth = 12 )
plt.plot(-x10,y10 , "black" , linewidth = 12 )
plt.plot(-x11,y11  , "black" , linewidth = 12 )
plt.plot(-x12,y12 , "black" , linewidth = 12 )
plt.plot(-x13,y13 , "black" , linewidth = 12 )
plt.plot(-x14,y14 , "black" , linewidth = 12 )
plt.plot([1.566 , 2.4]  ,  [-2.49 , -2.49] , "black" , linewidth = 12 )
plt.plot([-1.566 , -2.4]  ,  [-2.49 , -2.49] , "black" , linewidth = 12 )
plt.plot(-x15 , y15, "black" , linewidth = 12 )
plt.plot(-x16 , y16, "black" , linewidth = 12 )
plt.scatter(-5,-2.35 , s = 10000 , facecolors = "gray" ,edgecolors="black" , linewidth = 10.5 )
plt.plot(x17 , y17, "black" , linewidth = 12 )
plt.plot(-x17 , y17, "black" , linewidth = 12 )
plt.scatter(0,0 , s = 5000 , facecolors = "orange" ,edgecolors="red" , linewidths= 10)
plt.plot(x18 , y18, "black" , linewidth = 12 )
plt.plot(-x18 , y18, "black" , linewidth = 12 )
plt.plot(x19 , y19 , "red" , linewidth = 12)
plt.plot(x20 , y20 , "red" , linewidth = 12)
plt.plot(x21 , y21, "red" , linewidth = 12)
plt.plot(x22 , y22 , "red" , linewidth = 12)
plt.plot(-x22 , y22 , "red" , linewidth = 12)
plt.plot(x23 , y23 , "red" , linewidth = 12)
plt.plot(-x23 , y23 , "red" , linewidth = 12)
plt.plot(x24 , y24 , "red"  ,linewidth  = 12)
plt.plot(x25 , y25 , "red" , linewidth = 12)
plt.plot(x26 , y26 , "red" , linewidth = 12)
plt.plot(x27 , y27 , "red" , linewidth = 12)
plt.plot(x28 , y28 , "red" , linewidth = 12)

# %%
x28 = np.arange(1.4 ,0 ,-0.00001)


y28 = (-4.1277142857142857142857142857143 * x28) + 11

plt.figure(figsize = (20 , 20) )
plt.plot(x,y , "black" , linewidth = 12)
plt.plot(x1,y1 , "black" , linewidth = 12)
plt.plot(x2,y2, "black" , linewidth = 12)
plt.plot(x3,y3 , "black" , linewidth = 12)
plt.plot(-x4,y4, "black" , linewidth = 12)
plt.plot(x5 , y5, "black" , linewidth = 12)
plt.plot(x6 , y6, "black" , linewidth = 12)
plt.plot(x7,y7, "black" , linewidth = 12)
plt.plot(x8 , y8, "black" , linewidth = 12)
plt.plot(x9,y9, "black" , linewidth = 12)
plt.plot(x10,y10, "black" , linewidth = 12)
plt.plot(x11,y11, "black" , linewidth = 12)
plt.plot(x12,y12, "black" , linewidth = 12)
plt.plot(x13,y13, "black" , linewidth = 12)
plt.plot(x14,y14, "black" , linewidth = 12)
plt.plot(x15 , y15, "black" , linewidth = 12)
plt.plot(x16 , y16, "black" , linewidth = 12)
plt.scatter(5,-2.35 , s = 10000 ,facecolors = "gray" ,edgecolors="black" , linewidth = 10.5)
plt.plot(-x1,y1 , "black" , linewidth = 12)
plt.plot(-x2,y2 , "black" , linewidth = 12)
plt.plot(-x3,y3 , "black" , linewidth = 12)
plt.plot(-x5 , y5 , "black" , linewidth = 12)
plt.plot(-x6 , y6 , "black" , linewidth = 12)
plt.plot(-x7,y7 , "black" , linewidth = 12)
plt.plot(-x8 , y8  , "black" , linewidth = 12)
plt.plot(-x9,y9 , "black" , linewidth = 12 )
plt.plot(-x10,y10 , "black" , linewidth = 12 )
plt.plot(-x11,y11  , "black" , linewidth = 12 )
plt.plot(-x12,y12 , "black" , linewidth = 12 )
plt.plot(-x13,y13 , "black" , linewidth = 12 )
plt.plot(-x14,y14 , "black" , linewidth = 12 )
plt.plot([1.566 , 2.4]  ,  [-2.49 , -2.49] , "black" , linewidth = 12 )
plt.plot([-1.566 , -2.4]  ,  [-2.49 , -2.49] , "black" , linewidth = 12 )
plt.plot(-x15 , y15, "black" , linewidth = 12 )
plt.plot(-x16 , y16, "black" , linewidth = 12 )
plt.scatter(-5,-2.35 , s = 10000 , facecolors = "gray" ,edgecolors="black" , linewidth = 10.5 )
plt.plot(x17 , y17, "black" , linewidth = 12 )
plt.plot(-x17 , y17, "black" , linewidth = 12 )
plt.scatter(0,0 , s = 5000 , facecolors = "orange" ,edgecolors="red" , linewidths= 10)
plt.plot(x18 , y18, "black" , linewidth = 12 )
plt.plot(-x18 , y18, "black" , linewidth = 12 )
plt.plot(x19 , y19 , "red" , linewidth = 12)
plt.plot(x20 , y20 , "red" , linewidth = 12)
plt.plot(x21 , y21, "red" , linewidth = 12)
plt.plot(x22 , y22 , "red" , linewidth = 12)
plt.plot(-x22 , y22 , "red" , linewidth = 12)
plt.plot(x23 , y23 , "red" , linewidth = 12)
plt.plot(-x23 , y23 , "red" , linewidth = 12)
plt.plot(x24 , y24 , "red"  ,linewidth  = 12)
plt.plot(x25 , y25 , "red" , linewidth = 12)
plt.plot(x26 , y26 , "red" , linewidth = 12)
plt.plot(x27 , y27 , "red" , linewidth = 12)
plt.plot(x28 , y28 , "red" , linewidth = 12)

plt.scatter(4.5,-10 , s = 104000, facecolors = "none" ,edgecolors="orange" , linewidths= 20 , alpha = 1)

# %%
plt.figure(figsize = (20 , 20) )
plt.plot(x,y , "black" , linewidth = 12)
plt.plot(x1,y1 , "black" , linewidth = 12)
plt.plot(x2,y2, "black" , linewidth = 12)
plt.plot(x3,y3 , "black" , linewidth = 12)
plt.plot(-x4,y4, "black" , linewidth = 12)
plt.plot(x5 , y5, "black" , linewidth = 12)
plt.plot(x6 , y6, "black" , linewidth = 12)
plt.plot(x7,y7, "black" , linewidth = 12)
plt.plot(x8 , y8, "black" , linewidth = 12)
plt.plot(x9,y9, "black" , linewidth = 12)
plt.plot(x10,y10, "black" , linewidth = 12)
plt.plot(x11,y11, "black" , linewidth = 12)
plt.plot(x12,y12, "black" , linewidth = 12)
plt.plot(x13,y13, "black" , linewidth = 12)
plt.plot(x14,y14, "black" , linewidth = 12)
plt.plot(x15 , y15, "black" , linewidth = 12)
plt.plot(x16 , y16, "black" , linewidth = 12)
plt.scatter(5,-2.35 , s = 8000 ,facecolors = "gray" ,edgecolors="black" , linewidth = 12)
plt.plot(-x1,y1 , "black" , linewidth = 12)
plt.plot(-x2,y2 , "black" , linewidth = 12)
plt.plot(-x3,y3 , "black" , linewidth = 12)
plt.plot(-x5 , y5 , "black" , linewidth = 12)
plt.plot(-x6 , y6 , "black" , linewidth = 12)
plt.plot(-x7,y7 , "black" , linewidth = 12)
plt.plot(-x8 , y8  , "black" , linewidth = 12)
plt.plot(-x9,y9 , "black" , linewidth = 12 )
plt.plot(-x10,y10 , "black" , linewidth = 12 )
plt.plot(-x11,y11  , "black" , linewidth = 12 )
plt.plot(-x12,y12 , "black" , linewidth = 12 )
plt.plot(-x13,y13 , "black" , linewidth = 12 )
plt.plot(-x14,y14 , "black" , linewidth = 12 )
plt.plot([1.566 , 2.4]  ,  [-2.49 , -2.49] , "black" , linewidth = 12 )
plt.plot([-1.566 , -2.4]  ,  [-2.49 , -2.49] , "black" , linewidth = 12 )
plt.plot(-x15 , y15, "black" , linewidth = 12 )
plt.plot(-x16 , y16, "black" , linewidth = 12 )
plt.scatter(-5,-2.35 , s = 8000 , facecolors = "gray" ,edgecolors="black" , linewidth = 12 )
plt.plot(x17 , y17, "black" , linewidth = 12 )
plt.plot(-x17 , y17, "black" , linewidth = 12 )
plt.scatter(0,0 , s = 5000 , facecolors = "orange" ,edgecolors="red" , linewidths= 10)
plt.plot(x18 , y18, "black" , linewidth = 12 )
plt.plot(-x18 , y18, "black" , linewidth = 12 )
plt.plot(x19 , y19 , "red" , linewidth = 12)
plt.plot(x20 , y20 , "red" , linewidth = 12)
plt.plot(x21 , y21, "red" , linewidth = 12)
plt.plot(x22 , y22 , "red" , linewidth = 12)
plt.plot(-x22 , y22 , "red" , linewidth = 12)
plt.plot(x23 , y23 , "red" , linewidth = 12)
plt.plot(-x23 , y23 , "red" , linewidth = 12)
plt.plot(x24 , y24 , "red"  ,linewidth  = 12)
plt.plot(x25 , y25 , "red" , linewidth = 12)
plt.plot(x26 , y26 , "red" , linewidth = 12)
plt.plot(x27 , y27 , "red" , linewidth = 12)
plt.plot(x28 , y28 , "red" , linewidth = 12)

plt.scatter(4.5,-10 , s = 90000, facecolors = "none" ,edgecolors="orange" , linewidths= 20 , alpha = 1)
plt.scatter(-0.015,5.3 , s = 10000, facecolors = "orange" ,edgecolors="red" , linewidths= 8.5 , alpha = 1)

# %%
plt.figure(figsize = (20 , 20) )
plt.plot(x,y , "black" , linewidth = 12)
plt.plot(x1,y1 , "black" , linewidth = 12)
plt.plot(x2,y2, "black" , linewidth = 12)
plt.plot(x3,y3 , "black" , linewidth = 12)
plt.plot(-x4,y4, "black" , linewidth = 12)
plt.plot(x5 , y5, "black" , linewidth = 12)
plt.plot(x6 , y6, "black" , linewidth = 12)
plt.plot(x7,y7, "black" , linewidth = 12)
plt.plot(x8 , y8, "black" , linewidth = 12)
plt.plot(x9,y9, "black" , linewidth = 12)
plt.plot(x10,y10, "black" , linewidth = 12)
plt.plot(x11,y11, "black" , linewidth = 12)
plt.plot(x12,y12, "black" , linewidth = 12)
plt.plot(x13,y13, "black" , linewidth = 12)
plt.plot(x14,y14, "black" , linewidth = 12)
plt.plot(x15 , y15, "black" , linewidth = 12)
plt.plot(x16 , y16, "black" , linewidth = 12)
plt.scatter(5,-2.35 , s = 8000 ,facecolors = "gray" ,edgecolors="black" , linewidth = 12)
plt.plot(-x1,y1 , "black" , linewidth = 12)
plt.plot(-x2,y2 , "black" , linewidth = 12)
plt.plot(-x3,y3 , "black" , linewidth = 12)
plt.plot(-x5 , y5 , "black" , linewidth = 12)
plt.plot(-x6 , y6 , "black" , linewidth = 12)
plt.plot(-x7,y7 , "black" , linewidth = 12)
plt.plot(-x8 , y8  , "black" , linewidth = 12)
plt.plot(-x9,y9 , "black" , linewidth = 12 )
plt.plot(-x10,y10 , "black" , linewidth = 12 )
plt.plot(-x11,y11  , "black" , linewidth = 12 )
plt.plot(-x12,y12 , "black" , linewidth = 12 )
plt.plot(-x13,y13 , "black" , linewidth = 12 )
plt.plot(-x14,y14 , "black" , linewidth = 12 )
plt.plot([1.566 , 2.4]  ,  [-2.49 , -2.49] , "black" , linewidth = 12 )
plt.plot([-1.566 , -2.4]  ,  [-2.49 , -2.49] , "black" , linewidth = 12 )
plt.plot(-x15 , y15, "black" , linewidth = 12 )
plt.plot(-x16 , y16, "black" , linewidth = 12 )
plt.scatter(-5,-2.35 , s = 8000 , facecolors = "gray" ,edgecolors="black" , linewidth = 12 )
plt.plot(x17 , y17, "black" , linewidth = 12 )
plt.plot(-x17 , y17, "black" , linewidth = 12 )
plt.scatter(0,0 , s = 5000 , facecolors = "orange" ,edgecolors="red" , linewidths= 10)
plt.plot(x18 , y18, "black" , linewidth = 12 )
plt.plot(-x18 , y18, "black" , linewidth = 12 )
plt.plot(x19 , y19 , "red" , linewidth = 12)
plt.plot(x20 , y20 , "red" , linewidth = 12)
plt.plot(x21 , y21, "red" , linewidth = 12)
plt.plot(x22 , y22 , "red" , linewidth = 12)
plt.plot(-x22 , y22 , "red" , linewidth = 12)
plt.plot(x23 , y23 , "red" , linewidth = 12)
plt.plot(-x23 , y23 , "red" , linewidth = 12)
plt.plot(x24 , y24 , "red"  ,linewidth  = 12)
plt.plot(x25 , y25 , "red" , linewidth = 12)
plt.plot(x26 , y26 , "red" , linewidth = 12)
plt.plot(x27 , y27 , "red" , linewidth = 12)
plt.plot(x28 , y28 , "red" , linewidth = 12)

plt.scatter(4.5,-10 , s = 90000, facecolors = "none" ,edgecolors="orange" , linewidths= 20 , alpha = 1)
plt.scatter(-0.015,5.3 , s = 10000, facecolors = "orange" ,edgecolors="red" , linewidths= 8.5 , alpha = 1)


y29 = np.arange(-9.2 , - 3.0 , 0.0001)

x29 = (( (y29 + 4.5) * (y29 + 4.5) ) / (-15.5)) - 0.5

plt.plot(x29 , y29 , "black" , linewidth = 12)
